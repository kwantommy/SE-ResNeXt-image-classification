# %% [markdown]
# ## Using SE-ResNeXt for image classification
# - Writes test classification to csv using test generator
# - Squeeze and Excitation networks - https://arxiv.org/abs/1709.01507
# - ResNeXt architecture - https://arxiv.org/abs/1611.05431
# - Keras model - https://github.com/osmr/imgclsmob
# - Kerascv - https://pypi.org/project/kerascv/

# %%
import sys
import numpy
import matplotlib
import pandas
import keras

print('Python: {}'.format(sys.version))
print('Numpy: {}'.format(numpy.__version__))
print('Matplotlib: {}'.format(matplotlib.__version__))
print('Pandas: {}'.format(pandas.__version__))
print('Keras: {}'.format(keras.__version__))
# Out:
# Using TensorFlow backend.
# Python: 3.6.8 |Anaconda, Inc.| (default, Dec 29 2018, 19:04:46)
# [GCC 4.2.1 Compatible Clang 4.0.1 (tags/RELEASE_401/final)]
# Numpy: 1.16.4
# Matplotlib: 3.0.2
# Pandas: 0.23.4
# Keras: 2.2.4

# %%
from kerascv.model_provider import get_model as kecv_get_model

#set pretrained = True for Imagenet weights
base_model = kecv_get_model(
    name = "seresnext101_32x4d",
    pretrained = False)

# %% [markdown]
# Also available are SE-ResNeXts with different cardinalities and layers:
# - 'seresnext50_32x4d': seresnext50_32x4d,
# - 'seresnext101_32x4d': seresnext101_32x4d,
# - 'seresnext101_64x4d': seresnext101_64x4d,

# %%
#set trainable = false for transfer learning 

for layer in base_model.layers[:]:
    layer.trainable = True

# %% [markdown]
# Replace output dense layer of 1000 classes to your classification needs

# %%
base_model.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 224, 224, 3)  0
# __________________________________________________________________________________________________
# lambda_1 (Lambda)               (None, 230, 230, 3)  0           input_1[0][0]
# __________________________________________________________________________________________________
# features/init_block/conv/conv ( (None, 112, 112, 64) 9408        lambda_1[0][0]
# __________________________________________________________________________________________________
# features/init_block/conv/bn (Ba (None, 112, 112, 64) 256         features/init_block/conv/conv[0][
# __________________________________________________________________________________________________
# features/init_block/conv/activ  (None, 112, 112, 64) 0           features/init_block/conv/bn[0][0]
# __________________________________________________________________________________________________
# lambda_2 (Lambda)               (None, 114, 114, 64) 0           features/init_block/conv/activ[0]
# __________________________________________________________________________________________________
# features/init_block/pool/pool ( (None, 56, 56, 64)   0           lambda_2[0][0]
# __________________________________________________________________________________________________
# features/stage1/unit1/body/conv (None, 56, 56, 128)  8192        features/init_block/pool/pool[0][
# __________________________________________________________________________________________________
# features/stage1/unit1/body/conv (None, 56, 56, 128)  512         features/stage1/unit1/body/conv1/
# __________________________________________________________________________________________________
# features/stage1/unit1/body/conv (None, 56, 56, 128)  0           features/stage1/unit1/body/conv1/
# __________________________________________________________________________________________________
# lambda_3 (Lambda)               (None, 58, 58, 128)  0           features/stage1/unit1/body/conv1/
# __________________________________________________________________________________________________
# lambda_4 (Lambda)               (None, 58, 58, 4)    0           lambda_3[0][0]
# __________________________________________________________________________________________________
# lambda_5 (Lambda)               (None, 58, 58, 4)    0           lambda_3[0][0]
# __________________________________________________________________________________________________
# lambda_6 (Lambda)               (None, 58, 58, 4)    0           lambda_3[0][0]
# __________________________________________________________________________________________________
# lambda_7 (Lambda)               (None, 58, 58, 4)    0           lambda_3[0][0]
# __________________________________________________________________________________________________
# lambda_8 (Lambda)               (None, 58, 58, 4)    0           lambda_3[0][0]
# __________________________________________________________________________________________________
# lambda_9 (Lambda)               (None, 58, 58, 4)    0           lambda_3[0][0]
# __________________________________________________________________________________________________
# lambda_10 (Lambda)              (None, 58, 58, 4)    0           lambda_3[0][0]
# __________________________________________________________________________________________________
# lambda_11 (Lambda)              (None, 58, 58, 4)    0           lambda_3[0][0]
# __________________________________________________________________________________________________
# lambda_12 (Lambda)              (None, 58, 58, 4)    0           lambda_3[0][0]
# __________________________________________________________________________________________________
# lambda_13 (Lambda)              (None, 58, 58, 4)    0           lambda_3[0][0]
# __________________________________________________________________________________________________
# lambda_14 (Lambda)              (None, 58, 58, 4)    0           lambda_3[0][0]
# __________________________________________________________________________________________________
# lambda_15 (Lambda)              (None, 58, 58, 4)    0           lambda_3[0][0]
# __________________________________________________________________________________________________
# lambda_16 (Lambda)              (None, 58, 58, 4)    0           lambda_3[0][0]
# __________________________________________________________________________________________________
# lambda_17 (Lambda)              (None, 58, 58, 4)    0           lambda_3[0][0]
# __________________________________________________________________________________________________
# lambda_18 (Lambda)              (None, 58, 58, 4)    0           lambda_3[0][0]
# __________________________________________________________________________________________________
# lambda_19 (Lambda)              (None, 58, 58, 4)    0           lambda_3[0][0]
# __________________________________________________________________________________________________
# lambda_20 (Lambda)              (None, 58, 58, 4)    0           lambda_3[0][0]
# __________________________________________________________________________________________________
# lambda_21 (Lambda)              (None, 58, 58, 4)    0           lambda_3[0][0]
# __________________________________________________________________________________________________
# lambda_22 (Lambda)              (None, 58, 58, 4)    0           lambda_3[0][0]
# __________________________________________________________________________________________________
# lambda_23 (Lambda)              (None, 58, 58, 4)    0           lambda_3[0][0]
# __________________________________________________________________________________________________
# lambda_24 (Lambda)              (None, 58, 58, 4)    0           lambda_3[0][0]
# __________________________________________________________________________________________________
# lambda_25 (Lambda)              (None, 58, 58, 4)    0           lambda_3[0][0]
# __________________________________________________________________________________________________
# lambda_26 (Lambda)              (None, 58, 58, 4)    0           lambda_3[0][0]
# __________________________________________________________________________________________________
# lambda_27 (Lambda)              (None, 58, 58, 4)    0           lambda_3[0][0]
# __________________________________________________________________________________________________
# lambda_28 (Lambda)              (None, 58, 58, 4)    0           lambda_3[0][0]
# __________________________________________________________________________________________________
# lambda_29 (Lambda)              (None, 58, 58, 4)    0           lambda_3[0][0]
# __________________________________________________________________________________________________
# lambda_30 (Lambda)              (None, 58, 58, 4)    0           lambda_3[0][0]
# __________________________________________________________________________________________________
# lambda_31 (Lambda)              (None, 58, 58, 4)    0           lambda_3[0][0]
# __________________________________________________________________________________________________
# lambda_32 (Lambda)              (None, 58, 58, 4)    0           lambda_3[0][0]
# __________________________________________________________________________________________________
# lambda_33 (Lambda)              (None, 58, 58, 4)    0           lambda_3[0][0]
# __________________________________________________________________________________________________
# lambda_34 (Lambda)              (None, 58, 58, 4)    0           lambda_3[0][0]
# __________________________________________________________________________________________________
# lambda_35 (Lambda)              (None, 58, 58, 4)    0           lambda_3[0][0]
# __________________________________________________________________________________________________
# features/stage1/unit1/body/conv (None, 56, 56, 4)    144         lambda_4[0][0]
# __________________________________________________________________________________________________
# features/stage1/unit1/body/conv (None, 56, 56, 4)    144         lambda_5[0][0]
# __________________________________________________________________________________________________
# features/stage1/unit1/body/conv (None, 56, 56, 4)    144         lambda_6[0][0]
# __________________________________________________________________________________________________
# features/stage1/unit1/body/conv (None, 56, 56, 4)    144         lambda_7[0][0]
# __________________________________________________________________________________________________
# features/stage1/unit1/body/conv (None, 56, 56, 4)    144         lambda_8[0][0]
# __________________________________________________________________________________________________
# features/stage1/unit1/body/conv (None, 56, 56, 4)    144         lambda_9[0][0]
# __________________________________________________________________________________________________
# features/stage1/unit1/body/conv (None, 56, 56, 4)    144         lambda_10[0][0]
# __________________________________________________________________________________________________
# features/stage1/unit1/body/conv (None, 56, 56, 4)    144         lambda_11[0][0]
# __________________________________________________________________________________________________
# features/stage1/unit1/body/conv (None, 56, 56, 4)    144         lambda_12[0][0]
# __________________________________________________________________________________________________
# features/stage1/unit1/body/conv (None, 56, 56, 4)    144         lambda_13[0][0]
# __________________________________________________________________________________________________
# features/stage1/unit1/body/conv (None, 56, 56, 4)    144         lambda_14[0][0]
# __________________________________________________________________________________________________
# features/stage1/unit1/body/conv (None, 56, 56, 4)    144         lambda_15[0][0]
# __________________________________________________________________________________________________
# features/stage1/unit1/body/conv (None, 56, 56, 4)    144         lambda_16[0][0]
# __________________________________________________________________________________________________
# features/stage1/unit1/body/conv (None, 56, 56, 4)    144         lambda_17[0][0]
# __________________________________________________________________________________________________
# features/stage1/unit1/body/conv (None, 56, 56, 4)    144         lambda_18[0][0]
# __________________________________________________________________________________________________
# features/stage1/unit1/body/conv (None, 56, 56, 4)    144         lambda_19[0][0]
# __________________________________________________________________________________________________
# features/stage1/unit1/body/conv (None, 56, 56, 4)    144         lambda_20[0][0]
# __________________________________________________________________________________________________
# features/stage1/unit1/body/conv (None, 56, 56, 4)    144         lambda_21[0][0]
# __________________________________________________________________________________________________
# features/stage1/unit1/body/conv (None, 56, 56, 4)    144         lambda_22[0][0]
# __________________________________________________________________________________________________
# features/stage1/unit1/body/conv (None, 56, 56, 4)    144         lambda_23[0][0]
# __________________________________________________________________________________________________
# features/stage1/unit1/body/conv (None, 56, 56, 4)    144         lambda_24[0][0]
# __________________________________________________________________________________________________
# features/stage1/unit1/body/conv (None, 56, 56, 4)    144         lambda_25[0][0]
# __________________________________________________________________________________________________
# features/stage1/unit1/body/conv (None, 56, 56, 4)    144         lambda_26[0][0]
# __________________________________________________________________________________________________
# features/stage1/unit1/body/conv (None, 56, 56, 4)    144         lambda_27[0][0]
# __________________________________________________________________________________________________
# features/stage1/unit1/body/conv (None, 56, 56, 4)    144         lambda_28[0][0]
# __________________________________________________________________________________________________
# features/stage1/unit1/body/conv (None, 56, 56, 4)    144         lambda_29[0][0]
# __________________________________________________________________________________________________
# features/stage1/unit1/body/conv (None, 56, 56, 4)    144         lambda_30[0][0]
# __________________________________________________________________________________________________
# features/stage1/unit1/body/conv (None, 56, 56, 4)    144         lambda_31[0][0]
# __________________________________________________________________________________________________
# features/stage1/unit1/body/conv (None, 56, 56, 4)    144         lambda_32[0][0]
# __________________________________________________________________________________________________
# features/stage1/unit1/body/conv (None, 56, 56, 4)    144         lambda_33[0][0]
# __________________________________________________________________________________________________
# features/stage1/unit1/body/conv (None, 56, 56, 4)    144         lambda_34[0][0]
# __________________________________________________________________________________________________
# features/stage1/unit1/body/conv (None, 56, 56, 4)    144         lambda_35[0][0]
# __________________________________________________________________________________________________
# features/stage1/unit1/body/conv (None, 56, 56, 128)  0           features/stage1/unit1/body/conv2/
#                                                                  features/stage1/unit1/body/conv2/
#                                                                  features/stage1/unit1/body/conv2/
#                                                                  features/stage1/unit1/body/conv2/
#                                                                  features/stage1/unit1/body/conv2/
#                                                                  features/stage1/unit1/body/conv2/
#                                                                  features/stage1/unit1/body/conv2/
#                                                                  features/stage1/unit1/body/conv2/
#                                                                  features/stage1/unit1/body/conv2/
#                                                                  features/stage1/unit1/body/conv2/
#                                                                  features/stage1/unit1/body/conv2/
#                                                                  features/stage1/unit1/body/conv2/
#                                                                  features/stage1/unit1/body/conv2/
#                                                                  features/stage1/unit1/body/conv2/
#                                                                  features/stage1/unit1/body/conv2/
#                                                                  features/stage1/unit1/body/conv2/
#                                                                  features/stage1/unit1/body/conv2/
#                                                                  features/stage1/unit1/body/conv2/
#                                                                  features/stage1/unit1/body/conv2/
#                                                                  features/stage1/unit1/body/conv2/
#                                                                  features/stage1/unit1/body/conv2/
#                                                                  features/stage1/unit1/body/conv2/
#                                                                  features/stage1/unit1/body/conv2/
#                                                                  features/stage1/unit1/body/conv2/
#                                                                  features/stage1/unit1/body/conv2/
#                                                                  features/stage1/unit1/body/conv2/
#                                                                  features/stage1/unit1/body/conv2/
#                                                                  features/stage1/unit1/body/conv2/
#                                                                  features/stage1/unit1/body/conv2/
#                                                                  features/stage1/unit1/body/conv2/
#                                                                  features/stage1/unit1/body/conv2/
#                                                                  features/stage1/unit1/body/conv2/
# __________________________________________________________________________________________________
# features/stage1/unit1/body/conv (None, 56, 56, 128)  512         features/stage1/unit1/body/conv2/
# __________________________________________________________________________________________________
# features/stage1/unit1/body/conv (None, 56, 56, 128)  0           features/stage1/unit1/body/conv2/
# __________________________________________________________________________________________________
# features/stage1/unit1/body/conv (None, 56, 56, 256)  32768       features/stage1/unit1/body/conv2/
# __________________________________________________________________________________________________
# features/stage1/unit1/body/conv (None, 56, 56, 256)  1024        features/stage1/unit1/body/conv3/
# __________________________________________________________________________________________________
# features/stage1/unit1/se/pool ( (None, 1, 1, 256)    0           features/stage1/unit1/body/conv3/
# __________________________________________________________________________________________________
# features/stage1/unit1/se/conv1  (None, 1, 1, 16)     4112        features/stage1/unit1/se/pool[0][
# __________________________________________________________________________________________________
# features/stage1/unit1/se/relu ( (None, 1, 1, 16)     0           features/stage1/unit1/se/conv1[0]
# __________________________________________________________________________________________________
# features/stage1/unit1/se/conv2  (None, 1, 1, 256)    4352        features/stage1/unit1/se/relu[0][
# __________________________________________________________________________________________________
# features/stage1/unit1/se/sigmoi (None, 1, 1, 256)    0           features/stage1/unit1/se/conv2[0]
# __________________________________________________________________________________________________
# features/stage1/unit1/identity_ (None, 56, 56, 256)  16384       features/init_block/pool/pool[0][
# __________________________________________________________________________________________________
# features/stage1/unit1/se/mul (M (None, 56, 56, 256)  0           features/stage1/unit1/body/conv3/
#                                                                  features/stage1/unit1/se/sigmoid[
# __________________________________________________________________________________________________
# features/stage1/unit1/identity_ (None, 56, 56, 256)  1024        features/stage1/unit1/identity_co
# __________________________________________________________________________________________________
# features/stage1/unit1/add (Add) (None, 56, 56, 256)  0           features/stage1/unit1/se/mul[0][0
#                                                                  features/stage1/unit1/identity_co
# __________________________________________________________________________________________________
# features/stage1/unit1/activ (Ac (None, 56, 56, 256)  0           features/stage1/unit1/add[0][0]
# __________________________________________________________________________________________________
# features/stage1/unit2/body/conv (None, 56, 56, 128)  32768       features/stage1/unit1/activ[0][0]
# __________________________________________________________________________________________________
# features/stage1/unit2/body/conv (None, 56, 56, 128)  512         features/stage1/unit2/body/conv1/
# __________________________________________________________________________________________________
# features/stage1/unit2/body/conv (None, 56, 56, 128)  0           features/stage1/unit2/body/conv1/
# __________________________________________________________________________________________________
# lambda_36 (Lambda)              (None, 58, 58, 128)  0           features/stage1/unit2/body/conv1/
# __________________________________________________________________________________________________
# lambda_37 (Lambda)              (None, 58, 58, 4)    0           lambda_36[0][0]
# __________________________________________________________________________________________________
# lambda_38 (Lambda)              (None, 58, 58, 4)    0           lambda_36[0][0]
# __________________________________________________________________________________________________
# lambda_39 (Lambda)              (None, 58, 58, 4)    0           lambda_36[0][0]
# __________________________________________________________________________________________________
# lambda_40 (Lambda)              (None, 58, 58, 4)    0           lambda_36[0][0]
# __________________________________________________________________________________________________
# lambda_41 (Lambda)              (None, 58, 58, 4)    0           lambda_36[0][0]
# __________________________________________________________________________________________________
# lambda_42 (Lambda)              (None, 58, 58, 4)    0           lambda_36[0][0]
# __________________________________________________________________________________________________
# lambda_43 (Lambda)              (None, 58, 58, 4)    0           lambda_36[0][0]
# __________________________________________________________________________________________________
# lambda_44 (Lambda)              (None, 58, 58, 4)    0           lambda_36[0][0]
# __________________________________________________________________________________________________
# lambda_45 (Lambda)              (None, 58, 58, 4)    0           lambda_36[0][0]
# __________________________________________________________________________________________________
# lambda_46 (Lambda)              (None, 58, 58, 4)    0           lambda_36[0][0]
# __________________________________________________________________________________________________
# lambda_47 (Lambda)              (None, 58, 58, 4)    0           lambda_36[0][0]
# __________________________________________________________________________________________________
# lambda_48 (Lambda)              (None, 58, 58, 4)    0           lambda_36[0][0]
# __________________________________________________________________________________________________
# lambda_49 (Lambda)              (None, 58, 58, 4)    0           lambda_36[0][0]
# __________________________________________________________________________________________________
# lambda_50 (Lambda)              (None, 58, 58, 4)    0           lambda_36[0][0]
# __________________________________________________________________________________________________
# lambda_51 (Lambda)              (None, 58, 58, 4)    0           lambda_36[0][0]
# __________________________________________________________________________________________________
# lambda_52 (Lambda)              (None, 58, 58, 4)    0           lambda_36[0][0]
# __________________________________________________________________________________________________
# lambda_53 (Lambda)              (None, 58, 58, 4)    0           lambda_36[0][0]
# __________________________________________________________________________________________________
# lambda_54 (Lambda)              (None, 58, 58, 4)    0           lambda_36[0][0]
# __________________________________________________________________________________________________
# lambda_55 (Lambda)              (None, 58, 58, 4)    0           lambda_36[0][0]
# __________________________________________________________________________________________________
# lambda_56 (Lambda)              (None, 58, 58, 4)    0           lambda_36[0][0]
# __________________________________________________________________________________________________
# lambda_57 (Lambda)              (None, 58, 58, 4)    0           lambda_36[0][0]
# __________________________________________________________________________________________________
# lambda_58 (Lambda)              (None, 58, 58, 4)    0           lambda_36[0][0]
# __________________________________________________________________________________________________
# lambda_59 (Lambda)              (None, 58, 58, 4)    0           lambda_36[0][0]
# __________________________________________________________________________________________________
# lambda_60 (Lambda)              (None, 58, 58, 4)    0           lambda_36[0][0]
# __________________________________________________________________________________________________
# lambda_61 (Lambda)              (None, 58, 58, 4)    0           lambda_36[0][0]
# __________________________________________________________________________________________________
# lambda_62 (Lambda)              (None, 58, 58, 4)    0           lambda_36[0][0]
# __________________________________________________________________________________________________
# lambda_63 (Lambda)              (None, 58, 58, 4)    0           lambda_36[0][0]
# __________________________________________________________________________________________________
# lambda_64 (Lambda)              (None, 58, 58, 4)    0           lambda_36[0][0]
# __________________________________________________________________________________________________
# lambda_65 (Lambda)              (None, 58, 58, 4)    0           lambda_36[0][0]
# __________________________________________________________________________________________________
# lambda_66 (Lambda)              (None, 58, 58, 4)    0           lambda_36[0][0]
# __________________________________________________________________________________________________
# lambda_67 (Lambda)              (None, 58, 58, 4)    0           lambda_36[0][0]
# __________________________________________________________________________________________________
# lambda_68 (Lambda)              (None, 58, 58, 4)    0           lambda_36[0][0]
# __________________________________________________________________________________________________
# features/stage1/unit2/body/conv (None, 56, 56, 4)    144         lambda_37[0][0]
# __________________________________________________________________________________________________
# features/stage1/unit2/body/conv (None, 56, 56, 4)    144         lambda_38[0][0]
# __________________________________________________________________________________________________
# features/stage1/unit2/body/conv (None, 56, 56, 4)    144         lambda_39[0][0]
# __________________________________________________________________________________________________
# features/stage1/unit2/body/conv (None, 56, 56, 4)    144         lambda_40[0][0]
# __________________________________________________________________________________________________
# features/stage1/unit2/body/conv (None, 56, 56, 4)    144         lambda_41[0][0]
# __________________________________________________________________________________________________
# features/stage1/unit2/body/conv (None, 56, 56, 4)    144         lambda_42[0][0]
# __________________________________________________________________________________________________
# features/stage1/unit2/body/conv (None, 56, 56, 4)    144         lambda_43[0][0]
# __________________________________________________________________________________________________
# features/stage1/unit2/body/conv (None, 56, 56, 4)    144         lambda_44[0][0]
# __________________________________________________________________________________________________
# features/stage1/unit2/body/conv (None, 56, 56, 4)    144         lambda_45[0][0]
# __________________________________________________________________________________________________
# features/stage1/unit2/body/conv (None, 56, 56, 4)    144         lambda_46[0][0]
# __________________________________________________________________________________________________
# features/stage1/unit2/body/conv (None, 56, 56, 4)    144         lambda_47[0][0]
# __________________________________________________________________________________________________
# features/stage1/unit2/body/conv (None, 56, 56, 4)    144         lambda_48[0][0]
# __________________________________________________________________________________________________
# features/stage1/unit2/body/conv (None, 56, 56, 4)    144         lambda_49[0][0]
# __________________________________________________________________________________________________
# features/stage1/unit2/body/conv (None, 56, 56, 4)    144         lambda_50[0][0]
# __________________________________________________________________________________________________
# features/stage1/unit2/body/conv (None, 56, 56, 4)    144         lambda_51[0][0]
# __________________________________________________________________________________________________
# features/stage1/unit2/body/conv (None, 56, 56, 4)    144         lambda_52[0][0]
# __________________________________________________________________________________________________
# features/stage1/unit2/body/conv (None, 56, 56, 4)    144         lambda_53[0][0]
# __________________________________________________________________________________________________
# features/stage1/unit2/body/conv (None, 56, 56, 4)    144         lambda_54[0][0]
# __________________________________________________________________________________________________
# features/stage1/unit2/body/conv (None, 56, 56, 4)    144         lambda_55[0][0]
# __________________________________________________________________________________________________
# features/stage1/unit2/body/conv (None, 56, 56, 4)    144         lambda_56[0][0]
# __________________________________________________________________________________________________
# features/stage1/unit2/body/conv (None, 56, 56, 4)    144         lambda_57[0][0]
# __________________________________________________________________________________________________
# features/stage1/unit2/body/conv (None, 56, 56, 4)    144         lambda_58[0][0]
# __________________________________________________________________________________________________
# features/stage1/unit2/body/conv (None, 56, 56, 4)    144         lambda_59[0][0]
# __________________________________________________________________________________________________
# features/stage1/unit2/body/conv (None, 56, 56, 4)    144         lambda_60[0][0]
# __________________________________________________________________________________________________
# features/stage1/unit2/body/conv (None, 56, 56, 4)    144         lambda_61[0][0]
# __________________________________________________________________________________________________
# features/stage1/unit2/body/conv (None, 56, 56, 4)    144         lambda_62[0][0]
# __________________________________________________________________________________________________
# features/stage1/unit2/body/conv (None, 56, 56, 4)    144         lambda_63[0][0]
# __________________________________________________________________________________________________
# features/stage1/unit2/body/conv (None, 56, 56, 4)    144         lambda_64[0][0]
# __________________________________________________________________________________________________
# features/stage1/unit2/body/conv (None, 56, 56, 4)    144         lambda_65[0][0]
# __________________________________________________________________________________________________
# features/stage1/unit2/body/conv (None, 56, 56, 4)    144         lambda_66[0][0]
# __________________________________________________________________________________________________
# features/stage1/unit2/body/conv (None, 56, 56, 4)    144         lambda_67[0][0]
# __________________________________________________________________________________________________
# features/stage1/unit2/body/conv (None, 56, 56, 4)    144         lambda_68[0][0]
# __________________________________________________________________________________________________
# features/stage1/unit2/body/conv (None, 56, 56, 128)  0           features/stage1/unit2/body/conv2/
#                                                                  features/stage1/unit2/body/conv2/
#                                                                  features/stage1/unit2/body/conv2/
#                                                                  features/stage1/unit2/body/conv2/
#                                                                  features/stage1/unit2/body/conv2/
#                                                                  features/stage1/unit2/body/conv2/
#                                                                  features/stage1/unit2/body/conv2/
#                                                                  features/stage1/unit2/body/conv2/
#                                                                  features/stage1/unit2/body/conv2/
#                                                                  features/stage1/unit2/body/conv2/
#                                                                  features/stage1/unit2/body/conv2/
#                                                                  features/stage1/unit2/body/conv2/
#                                                                  features/stage1/unit2/body/conv2/
#                                                                  features/stage1/unit2/body/conv2/
#                                                                  features/stage1/unit2/body/conv2/
#                                                                  features/stage1/unit2/body/conv2/
#                                                                  features/stage1/unit2/body/conv2/
#                                                                  features/stage1/unit2/body/conv2/
#                                                                  features/stage1/unit2/body/conv2/
#                                                                  features/stage1/unit2/body/conv2/
#                                                                  features/stage1/unit2/body/conv2/
#                                                                  features/stage1/unit2/body/conv2/
#                                                                  features/stage1/unit2/body/conv2/
#                                                                  features/stage1/unit2/body/conv2/
#                                                                  features/stage1/unit2/body/conv2/
#                                                                  features/stage1/unit2/body/conv2/
#                                                                  features/stage1/unit2/body/conv2/
#                                                                  features/stage1/unit2/body/conv2/
#                                                                  features/stage1/unit2/body/conv2/
#                                                                  features/stage1/unit2/body/conv2/
#                                                                  features/stage1/unit2/body/conv2/
#                                                                  features/stage1/unit2/body/conv2/
# __________________________________________________________________________________________________
# features/stage1/unit2/body/conv (None, 56, 56, 128)  512         features/stage1/unit2/body/conv2/
# __________________________________________________________________________________________________
# features/stage1/unit2/body/conv (None, 56, 56, 128)  0           features/stage1/unit2/body/conv2/
# __________________________________________________________________________________________________
# features/stage1/unit2/body/conv (None, 56, 56, 256)  32768       features/stage1/unit2/body/conv2/
# __________________________________________________________________________________________________
# features/stage1/unit2/body/conv (None, 56, 56, 256)  1024        features/stage1/unit2/body/conv3/
# __________________________________________________________________________________________________
# features/stage1/unit2/se/pool ( (None, 1, 1, 256)    0           features/stage1/unit2/body/conv3/
# __________________________________________________________________________________________________
# features/stage1/unit2/se/conv1  (None, 1, 1, 16)     4112        features/stage1/unit2/se/pool[0][
# __________________________________________________________________________________________________
# features/stage1/unit2/se/relu ( (None, 1, 1, 16)     0           features/stage1/unit2/se/conv1[0]
# __________________________________________________________________________________________________
# features/stage1/unit2/se/conv2  (None, 1, 1, 256)    4352        features/stage1/unit2/se/relu[0][
# __________________________________________________________________________________________________
# features/stage1/unit2/se/sigmoi (None, 1, 1, 256)    0           features/stage1/unit2/se/conv2[0]
# __________________________________________________________________________________________________
# features/stage1/unit2/se/mul (M (None, 56, 56, 256)  0           features/stage1/unit2/body/conv3/
#                                                                  features/stage1/unit2/se/sigmoid[
# __________________________________________________________________________________________________
# features/stage1/unit2/add (Add) (None, 56, 56, 256)  0           features/stage1/unit2/se/mul[0][0
#                                                                  features/stage1/unit1/activ[0][0]
# __________________________________________________________________________________________________
# features/stage1/unit2/activ (Ac (None, 56, 56, 256)  0           features/stage1/unit2/add[0][0]
# __________________________________________________________________________________________________
# features/stage1/unit3/body/conv (None, 56, 56, 128)  32768       features/stage1/unit2/activ[0][0]
# __________________________________________________________________________________________________
# features/stage1/unit3/body/conv (None, 56, 56, 128)  512         features/stage1/unit3/body/conv1/
# __________________________________________________________________________________________________
# features/stage1/unit3/body/conv (None, 56, 56, 128)  0           features/stage1/unit3/body/conv1/
# __________________________________________________________________________________________________
# lambda_69 (Lambda)              (None, 58, 58, 128)  0           features/stage1/unit3/body/conv1/
# __________________________________________________________________________________________________
# lambda_70 (Lambda)              (None, 58, 58, 4)    0           lambda_69[0][0]
# __________________________________________________________________________________________________
# lambda_71 (Lambda)              (None, 58, 58, 4)    0           lambda_69[0][0]
# __________________________________________________________________________________________________
# lambda_72 (Lambda)              (None, 58, 58, 4)    0           lambda_69[0][0]
# __________________________________________________________________________________________________
# lambda_73 (Lambda)              (None, 58, 58, 4)    0           lambda_69[0][0]
# __________________________________________________________________________________________________
# lambda_74 (Lambda)              (None, 58, 58, 4)    0           lambda_69[0][0]
# __________________________________________________________________________________________________
# lambda_75 (Lambda)              (None, 58, 58, 4)    0           lambda_69[0][0]
# __________________________________________________________________________________________________
# lambda_76 (Lambda)              (None, 58, 58, 4)    0           lambda_69[0][0]
# __________________________________________________________________________________________________
# lambda_77 (Lambda)              (None, 58, 58, 4)    0           lambda_69[0][0]
# __________________________________________________________________________________________________
# lambda_78 (Lambda)              (None, 58, 58, 4)    0           lambda_69[0][0]
# __________________________________________________________________________________________________
# lambda_79 (Lambda)              (None, 58, 58, 4)    0           lambda_69[0][0]
# __________________________________________________________________________________________________
# lambda_80 (Lambda)              (None, 58, 58, 4)    0           lambda_69[0][0]
# __________________________________________________________________________________________________
# lambda_81 (Lambda)              (None, 58, 58, 4)    0           lambda_69[0][0]
# __________________________________________________________________________________________________
# lambda_82 (Lambda)              (None, 58, 58, 4)    0           lambda_69[0][0]
# __________________________________________________________________________________________________
# lambda_83 (Lambda)              (None, 58, 58, 4)    0           lambda_69[0][0]
# __________________________________________________________________________________________________
# lambda_84 (Lambda)              (None, 58, 58, 4)    0           lambda_69[0][0]
# __________________________________________________________________________________________________
# lambda_85 (Lambda)              (None, 58, 58, 4)    0           lambda_69[0][0]
# __________________________________________________________________________________________________
# lambda_86 (Lambda)              (None, 58, 58, 4)    0           lambda_69[0][0]
# __________________________________________________________________________________________________
# lambda_87 (Lambda)              (None, 58, 58, 4)    0           lambda_69[0][0]
# __________________________________________________________________________________________________
# lambda_88 (Lambda)              (None, 58, 58, 4)    0           lambda_69[0][0]
# __________________________________________________________________________________________________
# lambda_89 (Lambda)              (None, 58, 58, 4)    0           lambda_69[0][0]
# __________________________________________________________________________________________________
# lambda_90 (Lambda)              (None, 58, 58, 4)    0           lambda_69[0][0]
# __________________________________________________________________________________________________
# lambda_91 (Lambda)              (None, 58, 58, 4)    0           lambda_69[0][0]
# __________________________________________________________________________________________________
# lambda_92 (Lambda)              (None, 58, 58, 4)    0           lambda_69[0][0]
# __________________________________________________________________________________________________
# lambda_93 (Lambda)              (None, 58, 58, 4)    0           lambda_69[0][0]
# __________________________________________________________________________________________________
# lambda_94 (Lambda)              (None, 58, 58, 4)    0           lambda_69[0][0]
# __________________________________________________________________________________________________
# lambda_95 (Lambda)              (None, 58, 58, 4)    0           lambda_69[0][0]
# __________________________________________________________________________________________________
# lambda_96 (Lambda)              (None, 58, 58, 4)    0           lambda_69[0][0]
# __________________________________________________________________________________________________
# lambda_97 (Lambda)              (None, 58, 58, 4)    0           lambda_69[0][0]
# __________________________________________________________________________________________________
# lambda_98 (Lambda)              (None, 58, 58, 4)    0           lambda_69[0][0]
# __________________________________________________________________________________________________
# lambda_99 (Lambda)              (None, 58, 58, 4)    0           lambda_69[0][0]
# __________________________________________________________________________________________________
# lambda_100 (Lambda)             (None, 58, 58, 4)    0           lambda_69[0][0]
# __________________________________________________________________________________________________
# lambda_101 (Lambda)             (None, 58, 58, 4)    0           lambda_69[0][0]
# __________________________________________________________________________________________________
# features/stage1/unit3/body/conv (None, 56, 56, 4)    144         lambda_70[0][0]
# ...
# lambda_1077 (Lambda)            (None, 9, 9, 32)     0           lambda_1059[0][0]
# __________________________________________________________________________________________________
# lambda_1078 (Lambda)            (None, 9, 9, 32)     0           lambda_1059[0][0]
# __________________________________________________________________________________________________
# lambda_1079 (Lambda)            (None, 9, 9, 32)     0           lambda_1059[0][0]
# __________________________________________________________________________________________________
# lambda_1080 (Lambda)            (None, 9, 9, 32)     0           lambda_1059[0][0]
# __________________________________________________________________________________________________
# lambda_1081 (Lambda)            (None, 9, 9, 32)     0           lambda_1059[0][0]
# __________________________________________________________________________________________________
# lambda_1082 (Lambda)            (None, 9, 9, 32)     0           lambda_1059[0][0]
# __________________________________________________________________________________________________
# lambda_1083 (Lambda)            (None, 9, 9, 32)     0           lambda_1059[0][0]
# __________________________________________________________________________________________________
# lambda_1084 (Lambda)            (None, 9, 9, 32)     0           lambda_1059[0][0]
# __________________________________________________________________________________________________
# lambda_1085 (Lambda)            (None, 9, 9, 32)     0           lambda_1059[0][0]
# __________________________________________________________________________________________________
# lambda_1086 (Lambda)            (None, 9, 9, 32)     0           lambda_1059[0][0]
# __________________________________________________________________________________________________
# lambda_1087 (Lambda)            (None, 9, 9, 32)     0           lambda_1059[0][0]
# __________________________________________________________________________________________________
# lambda_1088 (Lambda)            (None, 9, 9, 32)     0           lambda_1059[0][0]
# __________________________________________________________________________________________________
# lambda_1089 (Lambda)            (None, 9, 9, 32)     0           lambda_1059[0][0]
# __________________________________________________________________________________________________
# lambda_1090 (Lambda)            (None, 9, 9, 32)     0           lambda_1059[0][0]
# __________________________________________________________________________________________________
# lambda_1091 (Lambda)            (None, 9, 9, 32)     0           lambda_1059[0][0]
# __________________________________________________________________________________________________
# features/stage4/unit3/body/conv (None, 7, 7, 32)     9216        lambda_1060[0][0]
# __________________________________________________________________________________________________
# features/stage4/unit3/body/conv (None, 7, 7, 32)     9216        lambda_1061[0][0]
# __________________________________________________________________________________________________
# features/stage4/unit3/body/conv (None, 7, 7, 32)     9216        lambda_1062[0][0]
# __________________________________________________________________________________________________
# features/stage4/unit3/body/conv (None, 7, 7, 32)     9216        lambda_1063[0][0]
# __________________________________________________________________________________________________
# features/stage4/unit3/body/conv (None, 7, 7, 32)     9216        lambda_1064[0][0]
# __________________________________________________________________________________________________
# features/stage4/unit3/body/conv (None, 7, 7, 32)     9216        lambda_1065[0][0]
# __________________________________________________________________________________________________
# features/stage4/unit3/body/conv (None, 7, 7, 32)     9216        lambda_1066[0][0]
# __________________________________________________________________________________________________
# features/stage4/unit3/body/conv (None, 7, 7, 32)     9216        lambda_1067[0][0]
# __________________________________________________________________________________________________
# features/stage4/unit3/body/conv (None, 7, 7, 32)     9216        lambda_1068[0][0]
# __________________________________________________________________________________________________
# features/stage4/unit3/body/conv (None, 7, 7, 32)     9216        lambda_1069[0][0]
# __________________________________________________________________________________________________
# features/stage4/unit3/body/conv (None, 7, 7, 32)     9216        lambda_1070[0][0]
# __________________________________________________________________________________________________
# features/stage4/unit3/body/conv (None, 7, 7, 32)     9216        lambda_1071[0][0]
# __________________________________________________________________________________________________
# features/stage4/unit3/body/conv (None, 7, 7, 32)     9216        lambda_1072[0][0]
# __________________________________________________________________________________________________
# features/stage4/unit3/body/conv (None, 7, 7, 32)     9216        lambda_1073[0][0]
# __________________________________________________________________________________________________
# features/stage4/unit3/body/conv (None, 7, 7, 32)     9216        lambda_1074[0][0]
# __________________________________________________________________________________________________
# features/stage4/unit3/body/conv (None, 7, 7, 32)     9216        lambda_1075[0][0]
# __________________________________________________________________________________________________
# features/stage4/unit3/body/conv (None, 7, 7, 32)     9216        lambda_1076[0][0]
# __________________________________________________________________________________________________
# features/stage4/unit3/body/conv (None, 7, 7, 32)     9216        lambda_1077[0][0]
# __________________________________________________________________________________________________
# features/stage4/unit3/body/conv (None, 7, 7, 32)     9216        lambda_1078[0][0]
# __________________________________________________________________________________________________
# features/stage4/unit3/body/conv (None, 7, 7, 32)     9216        lambda_1079[0][0]
# __________________________________________________________________________________________________
# features/stage4/unit3/body/conv (None, 7, 7, 32)     9216        lambda_1080[0][0]
# __________________________________________________________________________________________________
# features/stage4/unit3/body/conv (None, 7, 7, 32)     9216        lambda_1081[0][0]
# __________________________________________________________________________________________________
# features/stage4/unit3/body/conv (None, 7, 7, 32)     9216        lambda_1082[0][0]
# __________________________________________________________________________________________________
# features/stage4/unit3/body/conv (None, 7, 7, 32)     9216        lambda_1083[0][0]
# __________________________________________________________________________________________________
# features/stage4/unit3/body/conv (None, 7, 7, 32)     9216        lambda_1084[0][0]
# __________________________________________________________________________________________________
# features/stage4/unit3/body/conv (None, 7, 7, 32)     9216        lambda_1085[0][0]
# __________________________________________________________________________________________________
# features/stage4/unit3/body/conv (None, 7, 7, 32)     9216        lambda_1086[0][0]
# __________________________________________________________________________________________________
# features/stage4/unit3/body/conv (None, 7, 7, 32)     9216        lambda_1087[0][0]
# __________________________________________________________________________________________________
# features/stage4/unit3/body/conv (None, 7, 7, 32)     9216        lambda_1088[0][0]
# __________________________________________________________________________________________________
# features/stage4/unit3/body/conv (None, 7, 7, 32)     9216        lambda_1089[0][0]
# __________________________________________________________________________________________________
# features/stage4/unit3/body/conv (None, 7, 7, 32)     9216        lambda_1090[0][0]
# __________________________________________________________________________________________________
# features/stage4/unit3/body/conv (None, 7, 7, 32)     9216        lambda_1091[0][0]
# __________________________________________________________________________________________________
# features/stage4/unit3/body/conv (None, 7, 7, 1024)   0           features/stage4/unit3/body/conv2/
#                                                                  features/stage4/unit3/body/conv2/
#                                                                  features/stage4/unit3/body/conv2/
#                                                                  features/stage4/unit3/body/conv2/
#                                                                  features/stage4/unit3/body/conv2/
#                                                                  features/stage4/unit3/body/conv2/
#                                                                  features/stage4/unit3/body/conv2/
#                                                                  features/stage4/unit3/body/conv2/
#                                                                  features/stage4/unit3/body/conv2/
#                                                                  features/stage4/unit3/body/conv2/
#                                                                  features/stage4/unit3/body/conv2/
#                                                                  features/stage4/unit3/body/conv2/
#                                                                  features/stage4/unit3/body/conv2/
#                                                                  features/stage4/unit3/body/conv2/
#                                                                  features/stage4/unit3/body/conv2/
#                                                                  features/stage4/unit3/body/conv2/
#                                                                  features/stage4/unit3/body/conv2/
#                                                                  features/stage4/unit3/body/conv2/
#                                                                  features/stage4/unit3/body/conv2/
#                                                                  features/stage4/unit3/body/conv2/
#                                                                  features/stage4/unit3/body/conv2/
#                                                                  features/stage4/unit3/body/conv2/
#                                                                  features/stage4/unit3/body/conv2/
#                                                                  features/stage4/unit3/body/conv2/
#                                                                  features/stage4/unit3/body/conv2/
#                                                                  features/stage4/unit3/body/conv2/
#                                                                  features/stage4/unit3/body/conv2/
#                                                                  features/stage4/unit3/body/conv2/
#                                                                  features/stage4/unit3/body/conv2/
#                                                                  features/stage4/unit3/body/conv2/
#                                                                  features/stage4/unit3/body/conv2/
#                                                                  features/stage4/unit3/body/conv2/
# __________________________________________________________________________________________________
# features/stage4/unit3/body/conv (None, 7, 7, 1024)   4096        features/stage4/unit3/body/conv2/
# __________________________________________________________________________________________________
# features/stage4/unit3/body/conv (None, 7, 7, 1024)   0           features/stage4/unit3/body/conv2/
# __________________________________________________________________________________________________
# features/stage4/unit3/body/conv (None, 7, 7, 2048)   2097152     features/stage4/unit3/body/conv2/
# __________________________________________________________________________________________________
# features/stage4/unit3/body/conv (None, 7, 7, 2048)   8192        features/stage4/unit3/body/conv3/
# __________________________________________________________________________________________________
# features/stage4/unit3/se/pool ( (None, 1, 1, 2048)   0           features/stage4/unit3/body/conv3/
# __________________________________________________________________________________________________
# features/stage4/unit3/se/conv1  (None, 1, 1, 128)    262272      features/stage4/unit3/se/pool[0][
# __________________________________________________________________________________________________
# features/stage4/unit3/se/relu ( (None, 1, 1, 128)    0           features/stage4/unit3/se/conv1[0]
# __________________________________________________________________________________________________
# features/stage4/unit3/se/conv2  (None, 1, 1, 2048)   264192      features/stage4/unit3/se/relu[0][
# __________________________________________________________________________________________________
# features/stage4/unit3/se/sigmoi (None, 1, 1, 2048)   0           features/stage4/unit3/se/conv2[0]
# __________________________________________________________________________________________________
# features/stage4/unit3/se/mul (M (None, 7, 7, 2048)   0           features/stage4/unit3/body/conv3/
#                                                                  features/stage4/unit3/se/sigmoid[
# __________________________________________________________________________________________________
# features/stage4/unit3/add (Add) (None, 7, 7, 2048)   0           features/stage4/unit3/se/mul[0][0
#                                                                  features/stage4/unit2/activ[0][0]
# __________________________________________________________________________________________________
# features/stage4/unit3/activ (Ac (None, 7, 7, 2048)   0           features/stage4/unit3/add[0][0]
# __________________________________________________________________________________________________
# features/final_pool (AveragePoo (None, 1, 1, 2048)   0           features/stage4/unit3/activ[0][0]
# __________________________________________________________________________________________________
# lambda_1092 (Lambda)            (None, 2048)         0           features/final_pool[0][0]
# __________________________________________________________________________________________________
# output (Dense)                  (None, 1000)         2049000     lambda_1092[0][0]
# ==================================================================================================
# Total params: 49,093,272
# Trainable params: 48,955,416
# Non-trainable params: 137,856
# __________________________________________________________________________________________________

# %%
base_model.layers[-2]

# %% [markdown]
# Create a new model and remove the top dense layer

# %%
from keras.models import Model
from keras.layers.core import Dense, Lambda
from keras.layers.advanced_activations import LeakyReLU
from keras.layers.convolutional import Conv2D
from keras.layers.pooling import GlobalAveragePooling2D, GlobalMaxPooling2D, MaxPooling2D
from keras.layers import Input
from keras.layers.merge import concatenate, add
from keras.layers.normalization import BatchNormalization
from keras.regularizers import l2
from keras.utils.layer_utils import convert_all_kernels_in_model
from keras.utils.data_utils import get_file
from keras.engine.topology import get_source_inputs
from keras_applications.imagenet_utils import _obtain_input_shape
import keras.backend as K

model = Model(
    inputs = base_model.input,
    outputs = base_model.get_layer(index = -2).output)

model.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 224, 224, 3)  0
# __________________________________________________________________________________________________
# lambda_1 (Lambda)               (None, 230, 230, 3)  0           input_1[0][0]
# __________________________________________________________________________________________________
# features/init_block/conv/conv ( (None, 112, 112, 64) 9408        lambda_1[0][0]
# __________________________________________________________________________________________________
# features/init_block/conv/bn (Ba (None, 112, 112, 64) 256         features/init_block/conv/conv[0][
# __________________________________________________________________________________________________
# features/init_block/conv/activ  (None, 112, 112, 64) 0           features/init_block/conv/bn[0][0]
# __________________________________________________________________________________________________
# lambda_2 (Lambda)               (None, 114, 114, 64) 0           features/init_block/conv/activ[0]
# __________________________________________________________________________________________________
# features/init_block/pool/pool ( (None, 56, 56, 64)   0           lambda_2[0][0]
# __________________________________________________________________________________________________
# features/stage1/unit1/body/conv (None, 56, 56, 128)  8192        features/init_block/pool/pool[0][
# __________________________________________________________________________________________________
# features/stage1/unit1/body/conv (None, 56, 56, 128)  512         features/stage1/unit1/body/conv1/
# __________________________________________________________________________________________________
# features/stage1/unit1/body/conv (None, 56, 56, 128)  0           features/stage1/unit1/body/conv1/
# __________________________________________________________________________________________________
# lambda_3 (Lambda)               (None, 58, 58, 128)  0           features/stage1/unit1/body/conv1/
# __________________________________________________________________________________________________
# lambda_4 (Lambda)               (None, 58, 58, 4)    0           lambda_3[0][0]
# __________________________________________________________________________________________________
# lambda_5 (Lambda)               (None, 58, 58, 4)    0           lambda_3[0][0]
# __________________________________________________________________________________________________
# lambda_6 (Lambda)               (None, 58, 58, 4)    0           lambda_3[0][0]
# __________________________________________________________________________________________________
# lambda_7 (Lambda)               (None, 58, 58, 4)    0           lambda_3[0][0]
# __________________________________________________________________________________________________
# lambda_8 (Lambda)               (None, 58, 58, 4)    0           lambda_3[0][0]
# __________________________________________________________________________________________________
# lambda_9 (Lambda)               (None, 58, 58, 4)    0           lambda_3[0][0]
# __________________________________________________________________________________________________
# lambda_10 (Lambda)              (None, 58, 58, 4)    0           lambda_3[0][0]
# __________________________________________________________________________________________________
# lambda_11 (Lambda)              (None, 58, 58, 4)    0           lambda_3[0][0]
# __________________________________________________________________________________________________
# lambda_12 (Lambda)              (None, 58, 58, 4)    0           lambda_3[0][0]
# __________________________________________________________________________________________________
# lambda_13 (Lambda)              (None, 58, 58, 4)    0           lambda_3[0][0]
# __________________________________________________________________________________________________
# lambda_14 (Lambda)              (None, 58, 58, 4)    0           lambda_3[0][0]
# __________________________________________________________________________________________________
# lambda_15 (Lambda)              (None, 58, 58, 4)    0           lambda_3[0][0]
# __________________________________________________________________________________________________
# lambda_16 (Lambda)              (None, 58, 58, 4)    0           lambda_3[0][0]
# __________________________________________________________________________________________________
# lambda_17 (Lambda)              (None, 58, 58, 4)    0           lambda_3[0][0]
# __________________________________________________________________________________________________
# lambda_18 (Lambda)              (None, 58, 58, 4)    0           lambda_3[0][0]
# __________________________________________________________________________________________________
# lambda_19 (Lambda)              (None, 58, 58, 4)    0           lambda_3[0][0]
# __________________________________________________________________________________________________
# lambda_20 (Lambda)              (None, 58, 58, 4)    0           lambda_3[0][0]
# __________________________________________________________________________________________________
# lambda_21 (Lambda)              (None, 58, 58, 4)    0           lambda_3[0][0]
# __________________________________________________________________________________________________
# lambda_22 (Lambda)              (None, 58, 58, 4)    0           lambda_3[0][0]
# __________________________________________________________________________________________________
# lambda_23 (Lambda)              (None, 58, 58, 4)    0           lambda_3[0][0]
# __________________________________________________________________________________________________
# lambda_24 (Lambda)              (None, 58, 58, 4)    0           lambda_3[0][0]
# __________________________________________________________________________________________________
# lambda_25 (Lambda)              (None, 58, 58, 4)    0           lambda_3[0][0]
# __________________________________________________________________________________________________
# lambda_26 (Lambda)              (None, 58, 58, 4)    0           lambda_3[0][0]
# __________________________________________________________________________________________________
# lambda_27 (Lambda)              (None, 58, 58, 4)    0           lambda_3[0][0]
# __________________________________________________________________________________________________
# lambda_28 (Lambda)              (None, 58, 58, 4)    0           lambda_3[0][0]
# __________________________________________________________________________________________________
# lambda_29 (Lambda)              (None, 58, 58, 4)    0           lambda_3[0][0]
# __________________________________________________________________________________________________
# lambda_30 (Lambda)              (None, 58, 58, 4)    0           lambda_3[0][0]
# __________________________________________________________________________________________________
# lambda_31 (Lambda)              (None, 58, 58, 4)    0           lambda_3[0][0]
# __________________________________________________________________________________________________
# lambda_32 (Lambda)              (None, 58, 58, 4)    0           lambda_3[0][0]
# __________________________________________________________________________________________________
# lambda_33 (Lambda)              (None, 58, 58, 4)    0           lambda_3[0][0]
# __________________________________________________________________________________________________
# lambda_34 (Lambda)              (None, 58, 58, 4)    0           lambda_3[0][0]
# __________________________________________________________________________________________________
# lambda_35 (Lambda)              (None, 58, 58, 4)    0           lambda_3[0][0]
# __________________________________________________________________________________________________
# features/stage1/unit1/body/conv (None, 56, 56, 4)    144         lambda_4[0][0]
# __________________________________________________________________________________________________
# features/stage1/unit1/body/conv (None, 56, 56, 4)    144         lambda_5[0][0]
# __________________________________________________________________________________________________
# features/stage1/unit1/body/conv (None, 56, 56, 4)    144         lambda_6[0][0]
# __________________________________________________________________________________________________
# features/stage1/unit1/body/conv (None, 56, 56, 4)    144         lambda_7[0][0]
# __________________________________________________________________________________________________
# features/stage1/unit1/body/conv (None, 56, 56, 4)    144         lambda_8[0][0]
# __________________________________________________________________________________________________
# features/stage1/unit1/body/conv (None, 56, 56, 4)    144         lambda_9[0][0]
# __________________________________________________________________________________________________
# features/stage1/unit1/body/conv (None, 56, 56, 4)    144         lambda_10[0][0]
# __________________________________________________________________________________________________
# features/stage1/unit1/body/conv (None, 56, 56, 4)    144         lambda_11[0][0]
# __________________________________________________________________________________________________
# features/stage1/unit1/body/conv (None, 56, 56, 4)    144         lambda_12[0][0]
# __________________________________________________________________________________________________
# features/stage1/unit1/body/conv (None, 56, 56, 4)    144         lambda_13[0][0]
# __________________________________________________________________________________________________
# features/stage1/unit1/body/conv (None, 56, 56, 4)    144         lambda_14[0][0]
# __________________________________________________________________________________________________
# features/stage1/unit1/body/conv (None, 56, 56, 4)    144         lambda_15[0][0]
# __________________________________________________________________________________________________
# features/stage1/unit1/body/conv (None, 56, 56, 4)    144         lambda_16[0][0]
# __________________________________________________________________________________________________
# features/stage1/unit1/body/conv (None, 56, 56, 4)    144         lambda_17[0][0]
# __________________________________________________________________________________________________
# features/stage1/unit1/body/conv (None, 56, 56, 4)    144         lambda_18[0][0]
# __________________________________________________________________________________________________
# features/stage1/unit1/body/conv (None, 56, 56, 4)    144         lambda_19[0][0]
# __________________________________________________________________________________________________
# features/stage1/unit1/body/conv (None, 56, 56, 4)    144         lambda_20[0][0]
# __________________________________________________________________________________________________
# features/stage1/unit1/body/conv (None, 56, 56, 4)    144         lambda_21[0][0]
# __________________________________________________________________________________________________
# features/stage1/unit1/body/conv (None, 56, 56, 4)    144         lambda_22[0][0]
# __________________________________________________________________________________________________
# features/stage1/unit1/body/conv (None, 56, 56, 4)    144         lambda_23[0][0]
# __________________________________________________________________________________________________
# features/stage1/unit1/body/conv (None, 56, 56, 4)    144         lambda_24[0][0]
# __________________________________________________________________________________________________
# features/stage1/unit1/body/conv (None, 56, 56, 4)    144         lambda_25[0][0]
# __________________________________________________________________________________________________
# features/stage1/unit1/body/conv (None, 56, 56, 4)    144         lambda_26[0][0]
# __________________________________________________________________________________________________
# features/stage1/unit1/body/conv (None, 56, 56, 4)    144         lambda_27[0][0]
# __________________________________________________________________________________________________
# features/stage1/unit1/body/conv (None, 56, 56, 4)    144         lambda_28[0][0]
# __________________________________________________________________________________________________
# features/stage1/unit1/body/conv (None, 56, 56, 4)    144         lambda_29[0][0]
# __________________________________________________________________________________________________
# features/stage1/unit1/body/conv (None, 56, 56, 4)    144         lambda_30[0][0]
# __________________________________________________________________________________________________
# features/stage1/unit1/body/conv (None, 56, 56, 4)    144         lambda_31[0][0]
# __________________________________________________________________________________________________
# features/stage1/unit1/body/conv (None, 56, 56, 4)    144         lambda_32[0][0]
# __________________________________________________________________________________________________
# features/stage1/unit1/body/conv (None, 56, 56, 4)    144         lambda_33[0][0]
# __________________________________________________________________________________________________
# features/stage1/unit1/body/conv (None, 56, 56, 4)    144         lambda_34[0][0]
# __________________________________________________________________________________________________
# features/stage1/unit1/body/conv (None, 56, 56, 4)    144         lambda_35[0][0]
# __________________________________________________________________________________________________
# features/stage1/unit1/body/conv (None, 56, 56, 128)  0           features/stage1/unit1/body/conv2/
#                                                                  features/stage1/unit1/body/conv2/
#                                                                  features/stage1/unit1/body/conv2/
#                                                                  features/stage1/unit1/body/conv2/
#                                                                  features/stage1/unit1/body/conv2/
#                                                                  features/stage1/unit1/body/conv2/
#                                                                  features/stage1/unit1/body/conv2/
#                                                                  features/stage1/unit1/body/conv2/
#                                                                  features/stage1/unit1/body/conv2/
#                                                                  features/stage1/unit1/body/conv2/
#                                                                  features/stage1/unit1/body/conv2/
#                                                                  features/stage1/unit1/body/conv2/
#                                                                  features/stage1/unit1/body/conv2/
#                                                                  features/stage1/unit1/body/conv2/
#                                                                  features/stage1/unit1/body/conv2/
#                                                                  features/stage1/unit1/body/conv2/
#                                                                  features/stage1/unit1/body/conv2/
#                                                                  features/stage1/unit1/body/conv2/
#                                                                  features/stage1/unit1/body/conv2/
#                                                                  features/stage1/unit1/body/conv2/
#                                                                  features/stage1/unit1/body/conv2/
#                                                                  features/stage1/unit1/body/conv2/
#                                                                  features/stage1/unit1/body/conv2/
#                                                                  features/stage1/unit1/body/conv2/
#                                                                  features/stage1/unit1/body/conv2/
#                                                                  features/stage1/unit1/body/conv2/
#                                                                  features/stage1/unit1/body/conv2/
#                                                                  features/stage1/unit1/body/conv2/
#                                                                  features/stage1/unit1/body/conv2/
#                                                                  features/stage1/unit1/body/conv2/
#                                                                  features/stage1/unit1/body/conv2/
#                                                                  features/stage1/unit1/body/conv2/
# __________________________________________________________________________________________________
# features/stage1/unit1/body/conv (None, 56, 56, 128)  512         features/stage1/unit1/body/conv2/
# __________________________________________________________________________________________________
# features/stage1/unit1/body/conv (None, 56, 56, 128)  0           features/stage1/unit1/body/conv2/
# __________________________________________________________________________________________________
# features/stage1/unit1/body/conv (None, 56, 56, 256)  32768       features/stage1/unit1/body/conv2/
# __________________________________________________________________________________________________
# features/stage1/unit1/body/conv (None, 56, 56, 256)  1024        features/stage1/unit1/body/conv3/
# __________________________________________________________________________________________________
# features/stage1/unit1/se/pool ( (None, 1, 1, 256)    0           features/stage1/unit1/body/conv3/
# __________________________________________________________________________________________________
# features/stage1/unit1/se/conv1  (None, 1, 1, 16)     4112        features/stage1/unit1/se/pool[0][
# __________________________________________________________________________________________________
# features/stage1/unit1/se/relu ( (None, 1, 1, 16)     0           features/stage1/unit1/se/conv1[0]
# __________________________________________________________________________________________________
# features/stage1/unit1/se/conv2  (None, 1, 1, 256)    4352        features/stage1/unit1/se/relu[0][
# __________________________________________________________________________________________________
# features/stage1/unit1/se/sigmoi (None, 1, 1, 256)    0           features/stage1/unit1/se/conv2[0]
# __________________________________________________________________________________________________
# features/stage1/unit1/identity_ (None, 56, 56, 256)  16384       features/init_block/pool/pool[0][
# __________________________________________________________________________________________________
# features/stage1/unit1/se/mul (M (None, 56, 56, 256)  0           features/stage1/unit1/body/conv3/
#                                                                  features/stage1/unit1/se/sigmoid[
# __________________________________________________________________________________________________
# features/stage1/unit1/identity_ (None, 56, 56, 256)  1024        features/stage1/unit1/identity_co
# __________________________________________________________________________________________________
# features/stage1/unit1/add (Add) (None, 56, 56, 256)  0           features/stage1/unit1/se/mul[0][0
#                                                                  features/stage1/unit1/identity_co
# __________________________________________________________________________________________________
# features/stage1/unit1/activ (Ac (None, 56, 56, 256)  0           features/stage1/unit1/add[0][0]
# __________________________________________________________________________________________________
# features/stage1/unit2/body/conv (None, 56, 56, 128)  32768       features/stage1/unit1/activ[0][0]
# __________________________________________________________________________________________________
# features/stage1/unit2/body/conv (None, 56, 56, 128)  512         features/stage1/unit2/body/conv1/
# __________________________________________________________________________________________________
# features/stage1/unit2/body/conv (None, 56, 56, 128)  0           features/stage1/unit2/body/conv1/
# __________________________________________________________________________________________________
# lambda_36 (Lambda)              (None, 58, 58, 128)  0           features/stage1/unit2/body/conv1/
# __________________________________________________________________________________________________
# lambda_37 (Lambda)              (None, 58, 58, 4)    0           lambda_36[0][0]
# __________________________________________________________________________________________________
# lambda_38 (Lambda)              (None, 58, 58, 4)    0           lambda_36[0][0]
# __________________________________________________________________________________________________
# lambda_39 (Lambda)              (None, 58, 58, 4)    0           lambda_36[0][0]
# __________________________________________________________________________________________________
# lambda_40 (Lambda)              (None, 58, 58, 4)    0           lambda_36[0][0]
# __________________________________________________________________________________________________
# lambda_41 (Lambda)              (None, 58, 58, 4)    0           lambda_36[0][0]
# __________________________________________________________________________________________________
# lambda_42 (Lambda)              (None, 58, 58, 4)    0           lambda_36[0][0]
# __________________________________________________________________________________________________
# lambda_43 (Lambda)              (None, 58, 58, 4)    0           lambda_36[0][0]
# __________________________________________________________________________________________________
# lambda_44 (Lambda)              (None, 58, 58, 4)    0           lambda_36[0][0]
# __________________________________________________________________________________________________
# lambda_45 (Lambda)              (None, 58, 58, 4)    0           lambda_36[0][0]
# __________________________________________________________________________________________________
# lambda_46 (Lambda)              (None, 58, 58, 4)    0           lambda_36[0][0]
# __________________________________________________________________________________________________
# lambda_47 (Lambda)              (None, 58, 58, 4)    0           lambda_36[0][0]
# __________________________________________________________________________________________________
# lambda_48 (Lambda)              (None, 58, 58, 4)    0           lambda_36[0][0]
# __________________________________________________________________________________________________
# lambda_49 (Lambda)              (None, 58, 58, 4)    0           lambda_36[0][0]
# __________________________________________________________________________________________________
# lambda_50 (Lambda)              (None, 58, 58, 4)    0           lambda_36[0][0]
# __________________________________________________________________________________________________
# lambda_51 (Lambda)              (None, 58, 58, 4)    0           lambda_36[0][0]
# __________________________________________________________________________________________________
# lambda_52 (Lambda)              (None, 58, 58, 4)    0           lambda_36[0][0]
# __________________________________________________________________________________________________
# lambda_53 (Lambda)              (None, 58, 58, 4)    0           lambda_36[0][0]
# __________________________________________________________________________________________________
# lambda_54 (Lambda)              (None, 58, 58, 4)    0           lambda_36[0][0]
# __________________________________________________________________________________________________
# lambda_55 (Lambda)              (None, 58, 58, 4)    0           lambda_36[0][0]
# __________________________________________________________________________________________________
# lambda_56 (Lambda)              (None, 58, 58, 4)    0           lambda_36[0][0]
# __________________________________________________________________________________________________
# lambda_57 (Lambda)              (None, 58, 58, 4)    0           lambda_36[0][0]
# __________________________________________________________________________________________________
# lambda_58 (Lambda)              (None, 58, 58, 4)    0           lambda_36[0][0]
# __________________________________________________________________________________________________
# lambda_59 (Lambda)              (None, 58, 58, 4)    0           lambda_36[0][0]
# __________________________________________________________________________________________________
# lambda_60 (Lambda)              (None, 58, 58, 4)    0           lambda_36[0][0]
# __________________________________________________________________________________________________
# lambda_61 (Lambda)              (None, 58, 58, 4)    0           lambda_36[0][0]
# __________________________________________________________________________________________________
# lambda_62 (Lambda)              (None, 58, 58, 4)    0           lambda_36[0][0]
# __________________________________________________________________________________________________
# lambda_63 (Lambda)              (None, 58, 58, 4)    0           lambda_36[0][0]
# __________________________________________________________________________________________________
# lambda_64 (Lambda)              (None, 58, 58, 4)    0           lambda_36[0][0]
# __________________________________________________________________________________________________
# lambda_65 (Lambda)              (None, 58, 58, 4)    0           lambda_36[0][0]
# __________________________________________________________________________________________________
# lambda_66 (Lambda)              (None, 58, 58, 4)    0           lambda_36[0][0]
# __________________________________________________________________________________________________
# lambda_67 (Lambda)              (None, 58, 58, 4)    0           lambda_36[0][0]
# __________________________________________________________________________________________________
# lambda_68 (Lambda)              (None, 58, 58, 4)    0           lambda_36[0][0]
# __________________________________________________________________________________________________
# features/stage1/unit2/body/conv (None, 56, 56, 4)    144         lambda_37[0][0]
# __________________________________________________________________________________________________
# features/stage1/unit2/body/conv (None, 56, 56, 4)    144         lambda_38[0][0]
# __________________________________________________________________________________________________
# features/stage1/unit2/body/conv (None, 56, 56, 4)    144         lambda_39[0][0]
# __________________________________________________________________________________________________
# features/stage1/unit2/body/conv (None, 56, 56, 4)    144         lambda_40[0][0]
# __________________________________________________________________________________________________
# features/stage1/unit2/body/conv (None, 56, 56, 4)    144         lambda_41[0][0]
# __________________________________________________________________________________________________
# features/stage1/unit2/body/conv (None, 56, 56, 4)    144         lambda_42[0][0]
# __________________________________________________________________________________________________
# features/stage1/unit2/body/conv (None, 56, 56, 4)    144         lambda_43[0][0]
# __________________________________________________________________________________________________
# features/stage1/unit2/body/conv (None, 56, 56, 4)    144         lambda_44[0][0]
# __________________________________________________________________________________________________
# features/stage1/unit2/body/conv (None, 56, 56, 4)    144         lambda_45[0][0]
# __________________________________________________________________________________________________
# features/stage1/unit2/body/conv (None, 56, 56, 4)    144         lambda_46[0][0]
# __________________________________________________________________________________________________
# features/stage1/unit2/body/conv (None, 56, 56, 4)    144         lambda_47[0][0]
# __________________________________________________________________________________________________
# features/stage1/unit2/body/conv (None, 56, 56, 4)    144         lambda_48[0][0]
# __________________________________________________________________________________________________
# features/stage1/unit2/body/conv (None, 56, 56, 4)    144         lambda_49[0][0]
# __________________________________________________________________________________________________
# features/stage1/unit2/body/conv (None, 56, 56, 4)    144         lambda_50[0][0]
# __________________________________________________________________________________________________
# features/stage1/unit2/body/conv (None, 56, 56, 4)    144         lambda_51[0][0]
# __________________________________________________________________________________________________
# features/stage1/unit2/body/conv (None, 56, 56, 4)    144         lambda_52[0][0]
# __________________________________________________________________________________________________
# features/stage1/unit2/body/conv (None, 56, 56, 4)    144         lambda_53[0][0]
# __________________________________________________________________________________________________
# features/stage1/unit2/body/conv (None, 56, 56, 4)    144         lambda_54[0][0]
# __________________________________________________________________________________________________
# features/stage1/unit2/body/conv (None, 56, 56, 4)    144         lambda_55[0][0]
# __________________________________________________________________________________________________
# features/stage1/unit2/body/conv (None, 56, 56, 4)    144         lambda_56[0][0]
# __________________________________________________________________________________________________
# features/stage1/unit2/body/conv (None, 56, 56, 4)    144         lambda_57[0][0]
# __________________________________________________________________________________________________
# features/stage1/unit2/body/conv (None, 56, 56, 4)    144         lambda_58[0][0]
# __________________________________________________________________________________________________
# features/stage1/unit2/body/conv (None, 56, 56, 4)    144         lambda_59[0][0]
# __________________________________________________________________________________________________
# features/stage1/unit2/body/conv (None, 56, 56, 4)    144         lambda_60[0][0]
# __________________________________________________________________________________________________
# features/stage1/unit2/body/conv (None, 56, 56, 4)    144         lambda_61[0][0]
# __________________________________________________________________________________________________
# features/stage1/unit2/body/conv (None, 56, 56, 4)    144         lambda_62[0][0]
# __________________________________________________________________________________________________
# features/stage1/unit2/body/conv (None, 56, 56, 4)    144         lambda_63[0][0]
# __________________________________________________________________________________________________
# features/stage1/unit2/body/conv (None, 56, 56, 4)    144         lambda_64[0][0]
# __________________________________________________________________________________________________
# features/stage1/unit2/body/conv (None, 56, 56, 4)    144         lambda_65[0][0]
# __________________________________________________________________________________________________
# features/stage1/unit2/body/conv (None, 56, 56, 4)    144         lambda_66[0][0]
# __________________________________________________________________________________________________
# features/stage1/unit2/body/conv (None, 56, 56, 4)    144         lambda_67[0][0]
# __________________________________________________________________________________________________
# features/stage1/unit2/body/conv (None, 56, 56, 4)    144         lambda_68[0][0]
# __________________________________________________________________________________________________
# features/stage1/unit2/body/conv (None, 56, 56, 128)  0           features/stage1/unit2/body/conv2/
#                                                                  features/stage1/unit2/body/conv2/
#                                                                  features/stage1/unit2/body/conv2/
#                                                                  features/stage1/unit2/body/conv2/
#                                                                  features/stage1/unit2/body/conv2/
#                                                                  features/stage1/unit2/body/conv2/
#                                                                  features/stage1/unit2/body/conv2/
#                                                                  features/stage1/unit2/body/conv2/
#                                                                  features/stage1/unit2/body/conv2/
#                                                                  features/stage1/unit2/body/conv2/
#                                                                  features/stage1/unit2/body/conv2/
#                                                                  features/stage1/unit2/body/conv2/
#                                                                  features/stage1/unit2/body/conv2/
#                                                                  features/stage1/unit2/body/conv2/
#                                                                  features/stage1/unit2/body/conv2/
#                                                                  features/stage1/unit2/body/conv2/
#                                                                  features/stage1/unit2/body/conv2/
#                                                                  features/stage1/unit2/body/conv2/
#                                                                  features/stage1/unit2/body/conv2/
#                                                                  features/stage1/unit2/body/conv2/
#                                                                  features/stage1/unit2/body/conv2/
#                                                                  features/stage1/unit2/body/conv2/
#                                                                  features/stage1/unit2/body/conv2/
#                                                                  features/stage1/unit2/body/conv2/
#                                                                  features/stage1/unit2/body/conv2/
#                                                                  features/stage1/unit2/body/conv2/
#                                                                  features/stage1/unit2/body/conv2/
#                                                                  features/stage1/unit2/body/conv2/
#                                                                  features/stage1/unit2/body/conv2/
#                                                                  features/stage1/unit2/body/conv2/
#                                                                  features/stage1/unit2/body/conv2/
#                                                                  features/stage1/unit2/body/conv2/
# __________________________________________________________________________________________________
# features/stage1/unit2/body/conv (None, 56, 56, 128)  512         features/stage1/unit2/body/conv2/
# __________________________________________________________________________________________________
# features/stage1/unit2/body/conv (None, 56, 56, 128)  0           features/stage1/unit2/body/conv2/
# __________________________________________________________________________________________________
# features/stage1/unit2/body/conv (None, 56, 56, 256)  32768       features/stage1/unit2/body/conv2/
# __________________________________________________________________________________________________
# features/stage1/unit2/body/conv (None, 56, 56, 256)  1024        features/stage1/unit2/body/conv3/
# __________________________________________________________________________________________________
# features/stage1/unit2/se/pool ( (None, 1, 1, 256)    0           features/stage1/unit2/body/conv3/
# __________________________________________________________________________________________________
# features/stage1/unit2/se/conv1  (None, 1, 1, 16)     4112        features/stage1/unit2/se/pool[0][
# __________________________________________________________________________________________________
# features/stage1/unit2/se/relu ( (None, 1, 1, 16)     0           features/stage1/unit2/se/conv1[0]
# __________________________________________________________________________________________________
# features/stage1/unit2/se/conv2  (None, 1, 1, 256)    4352        features/stage1/unit2/se/relu[0][
# __________________________________________________________________________________________________
# features/stage1/unit2/se/sigmoi (None, 1, 1, 256)    0           features/stage1/unit2/se/conv2[0]
# __________________________________________________________________________________________________
# features/stage1/unit2/se/mul (M (None, 56, 56, 256)  0           features/stage1/unit2/body/conv3/
#                                                                  features/stage1/unit2/se/sigmoid[
# __________________________________________________________________________________________________
# features/stage1/unit2/add (Add) (None, 56, 56, 256)  0           features/stage1/unit2/se/mul[0][0
#                                                                  features/stage1/unit1/activ[0][0]
# __________________________________________________________________________________________________
# features/stage1/unit2/activ (Ac (None, 56, 56, 256)  0           features/stage1/unit2/add[0][0]
# __________________________________________________________________________________________________
# features/stage1/unit3/body/conv (None, 56, 56, 128)  32768       features/stage1/unit2/activ[0][0]
# __________________________________________________________________________________________________
# features/stage1/unit3/body/conv (None, 56, 56, 128)  512         features/stage1/unit3/body/conv1/
# __________________________________________________________________________________________________
# features/stage1/unit3/body/conv (None, 56, 56, 128)  0           features/stage1/unit3/body/conv1/
# __________________________________________________________________________________________________
# lambda_69 (Lambda)              (None, 58, 58, 128)  0           features/stage1/unit3/body/conv1/
# __________________________________________________________________________________________________
# lambda_70 (Lambda)              (None, 58, 58, 4)    0           lambda_69[0][0]
# __________________________________________________________________________________________________
# lambda_71 (Lambda)              (None, 58, 58, 4)    0           lambda_69[0][0]
# __________________________________________________________________________________________________
# lambda_72 (Lambda)              (None, 58, 58, 4)    0           lambda_69[0][0]
# __________________________________________________________________________________________________
# lambda_73 (Lambda)              (None, 58, 58, 4)    0           lambda_69[0][0]
# __________________________________________________________________________________________________
# lambda_74 (Lambda)              (None, 58, 58, 4)    0           lambda_69[0][0]
# __________________________________________________________________________________________________
# lambda_75 (Lambda)              (None, 58, 58, 4)    0           lambda_69[0][0]
# __________________________________________________________________________________________________
# lambda_76 (Lambda)              (None, 58, 58, 4)    0           lambda_69[0][0]
# __________________________________________________________________________________________________
# lambda_77 (Lambda)              (None, 58, 58, 4)    0           lambda_69[0][0]
# __________________________________________________________________________________________________
# lambda_78 (Lambda)              (None, 58, 58, 4)    0           lambda_69[0][0]
# __________________________________________________________________________________________________
# lambda_79 (Lambda)              (None, 58, 58, 4)    0           lambda_69[0][0]
# __________________________________________________________________________________________________
# lambda_80 (Lambda)              (None, 58, 58, 4)    0           lambda_69[0][0]
# __________________________________________________________________________________________________
# lambda_81 (Lambda)              (None, 58, 58, 4)    0           lambda_69[0][0]
# __________________________________________________________________________________________________
# lambda_82 (Lambda)              (None, 58, 58, 4)    0           lambda_69[0][0]
# __________________________________________________________________________________________________
# lambda_83 (Lambda)              (None, 58, 58, 4)    0           lambda_69[0][0]
# __________________________________________________________________________________________________
# lambda_84 (Lambda)              (None, 58, 58, 4)    0           lambda_69[0][0]
# __________________________________________________________________________________________________
# lambda_85 (Lambda)              (None, 58, 58, 4)    0           lambda_69[0][0]
# __________________________________________________________________________________________________
# lambda_86 (Lambda)              (None, 58, 58, 4)    0           lambda_69[0][0]
# __________________________________________________________________________________________________
# lambda_87 (Lambda)              (None, 58, 58, 4)    0           lambda_69[0][0]
# __________________________________________________________________________________________________
# lambda_88 (Lambda)              (None, 58, 58, 4)    0           lambda_69[0][0]
# __________________________________________________________________________________________________
# lambda_89 (Lambda)              (None, 58, 58, 4)    0           lambda_69[0][0]
# __________________________________________________________________________________________________
# lambda_90 (Lambda)              (None, 58, 58, 4)    0           lambda_69[0][0]
# __________________________________________________________________________________________________
# lambda_91 (Lambda)              (None, 58, 58, 4)    0           lambda_69[0][0]
# __________________________________________________________________________________________________
# lambda_92 (Lambda)              (None, 58, 58, 4)    0           lambda_69[0][0]
# __________________________________________________________________________________________________
# lambda_93 (Lambda)              (None, 58, 58, 4)    0           lambda_69[0][0]
# __________________________________________________________________________________________________
# lambda_94 (Lambda)              (None, 58, 58, 4)    0           lambda_69[0][0]
# __________________________________________________________________________________________________
# lambda_95 (Lambda)              (None, 58, 58, 4)    0           lambda_69[0][0]
# __________________________________________________________________________________________________
# lambda_96 (Lambda)              (None, 58, 58, 4)    0           lambda_69[0][0]
# __________________________________________________________________________________________________
# lambda_97 (Lambda)              (None, 58, 58, 4)    0           lambda_69[0][0]
# __________________________________________________________________________________________________
# lambda_98 (Lambda)              (None, 58, 58, 4)    0           lambda_69[0][0]
# __________________________________________________________________________________________________
# lambda_99 (Lambda)              (None, 58, 58, 4)    0           lambda_69[0][0]
# __________________________________________________________________________________________________
# lambda_100 (Lambda)             (None, 58, 58, 4)    0           lambda_69[0][0]
# __________________________________________________________________________________________________
# lambda_101 (Lambda)             (None, 58, 58, 4)    0           lambda_69[0][0]
# __________________________________________________________________________________________________
# features/stage1/unit3/body/conv (None, 56, 56, 4)    144         lambda_70[0][0]
# ...
# lambda_1076 (Lambda)            (None, 9, 9, 32)     0           lambda_1059[0][0]
# __________________________________________________________________________________________________
# lambda_1077 (Lambda)            (None, 9, 9, 32)     0           lambda_1059[0][0]
# __________________________________________________________________________________________________
# lambda_1078 (Lambda)            (None, 9, 9, 32)     0           lambda_1059[0][0]
# __________________________________________________________________________________________________
# lambda_1079 (Lambda)            (None, 9, 9, 32)     0           lambda_1059[0][0]
# __________________________________________________________________________________________________
# lambda_1080 (Lambda)            (None, 9, 9, 32)     0           lambda_1059[0][0]
# __________________________________________________________________________________________________
# lambda_1081 (Lambda)            (None, 9, 9, 32)     0           lambda_1059[0][0]
# __________________________________________________________________________________________________
# lambda_1082 (Lambda)            (None, 9, 9, 32)     0           lambda_1059[0][0]
# __________________________________________________________________________________________________
# lambda_1083 (Lambda)            (None, 9, 9, 32)     0           lambda_1059[0][0]
# __________________________________________________________________________________________________
# lambda_1084 (Lambda)            (None, 9, 9, 32)     0           lambda_1059[0][0]
# __________________________________________________________________________________________________
# lambda_1085 (Lambda)            (None, 9, 9, 32)     0           lambda_1059[0][0]
# __________________________________________________________________________________________________
# lambda_1086 (Lambda)            (None, 9, 9, 32)     0           lambda_1059[0][0]
# __________________________________________________________________________________________________
# lambda_1087 (Lambda)            (None, 9, 9, 32)     0           lambda_1059[0][0]
# __________________________________________________________________________________________________
# lambda_1088 (Lambda)            (None, 9, 9, 32)     0           lambda_1059[0][0]
# __________________________________________________________________________________________________
# lambda_1089 (Lambda)            (None, 9, 9, 32)     0           lambda_1059[0][0]
# __________________________________________________________________________________________________
# lambda_1090 (Lambda)            (None, 9, 9, 32)     0           lambda_1059[0][0]
# __________________________________________________________________________________________________
# lambda_1091 (Lambda)            (None, 9, 9, 32)     0           lambda_1059[0][0]
# __________________________________________________________________________________________________
# features/stage4/unit3/body/conv (None, 7, 7, 32)     9216        lambda_1060[0][0]
# __________________________________________________________________________________________________
# features/stage4/unit3/body/conv (None, 7, 7, 32)     9216        lambda_1061[0][0]
# __________________________________________________________________________________________________
# features/stage4/unit3/body/conv (None, 7, 7, 32)     9216        lambda_1062[0][0]
# __________________________________________________________________________________________________
# features/stage4/unit3/body/conv (None, 7, 7, 32)     9216        lambda_1063[0][0]
# __________________________________________________________________________________________________
# features/stage4/unit3/body/conv (None, 7, 7, 32)     9216        lambda_1064[0][0]
# __________________________________________________________________________________________________
# features/stage4/unit3/body/conv (None, 7, 7, 32)     9216        lambda_1065[0][0]
# __________________________________________________________________________________________________
# features/stage4/unit3/body/conv (None, 7, 7, 32)     9216        lambda_1066[0][0]
# __________________________________________________________________________________________________
# features/stage4/unit3/body/conv (None, 7, 7, 32)     9216        lambda_1067[0][0]
# __________________________________________________________________________________________________
# features/stage4/unit3/body/conv (None, 7, 7, 32)     9216        lambda_1068[0][0]
# __________________________________________________________________________________________________
# features/stage4/unit3/body/conv (None, 7, 7, 32)     9216        lambda_1069[0][0]
# __________________________________________________________________________________________________
# features/stage4/unit3/body/conv (None, 7, 7, 32)     9216        lambda_1070[0][0]
# __________________________________________________________________________________________________
# features/stage4/unit3/body/conv (None, 7, 7, 32)     9216        lambda_1071[0][0]
# __________________________________________________________________________________________________
# features/stage4/unit3/body/conv (None, 7, 7, 32)     9216        lambda_1072[0][0]
# __________________________________________________________________________________________________
# features/stage4/unit3/body/conv (None, 7, 7, 32)     9216        lambda_1073[0][0]
# __________________________________________________________________________________________________
# features/stage4/unit3/body/conv (None, 7, 7, 32)     9216        lambda_1074[0][0]
# __________________________________________________________________________________________________
# features/stage4/unit3/body/conv (None, 7, 7, 32)     9216        lambda_1075[0][0]
# __________________________________________________________________________________________________
# features/stage4/unit3/body/conv (None, 7, 7, 32)     9216        lambda_1076[0][0]
# __________________________________________________________________________________________________
# features/stage4/unit3/body/conv (None, 7, 7, 32)     9216        lambda_1077[0][0]
# __________________________________________________________________________________________________
# features/stage4/unit3/body/conv (None, 7, 7, 32)     9216        lambda_1078[0][0]
# __________________________________________________________________________________________________
# features/stage4/unit3/body/conv (None, 7, 7, 32)     9216        lambda_1079[0][0]
# __________________________________________________________________________________________________
# features/stage4/unit3/body/conv (None, 7, 7, 32)     9216        lambda_1080[0][0]
# __________________________________________________________________________________________________
# features/stage4/unit3/body/conv (None, 7, 7, 32)     9216        lambda_1081[0][0]
# __________________________________________________________________________________________________
# features/stage4/unit3/body/conv (None, 7, 7, 32)     9216        lambda_1082[0][0]
# __________________________________________________________________________________________________
# features/stage4/unit3/body/conv (None, 7, 7, 32)     9216        lambda_1083[0][0]
# __________________________________________________________________________________________________
# features/stage4/unit3/body/conv (None, 7, 7, 32)     9216        lambda_1084[0][0]
# __________________________________________________________________________________________________
# features/stage4/unit3/body/conv (None, 7, 7, 32)     9216        lambda_1085[0][0]
# __________________________________________________________________________________________________
# features/stage4/unit3/body/conv (None, 7, 7, 32)     9216        lambda_1086[0][0]
# __________________________________________________________________________________________________
# features/stage4/unit3/body/conv (None, 7, 7, 32)     9216        lambda_1087[0][0]
# __________________________________________________________________________________________________
# features/stage4/unit3/body/conv (None, 7, 7, 32)     9216        lambda_1088[0][0]
# __________________________________________________________________________________________________
# features/stage4/unit3/body/conv (None, 7, 7, 32)     9216        lambda_1089[0][0]
# __________________________________________________________________________________________________
# features/stage4/unit3/body/conv (None, 7, 7, 32)     9216        lambda_1090[0][0]
# __________________________________________________________________________________________________
# features/stage4/unit3/body/conv (None, 7, 7, 32)     9216        lambda_1091[0][0]
# __________________________________________________________________________________________________
# features/stage4/unit3/body/conv (None, 7, 7, 1024)   0           features/stage4/unit3/body/conv2/
#                                                                  features/stage4/unit3/body/conv2/
#                                                                  features/stage4/unit3/body/conv2/
#                                                                  features/stage4/unit3/body/conv2/
#                                                                  features/stage4/unit3/body/conv2/
#                                                                  features/stage4/unit3/body/conv2/
#                                                                  features/stage4/unit3/body/conv2/
#                                                                  features/stage4/unit3/body/conv2/
#                                                                  features/stage4/unit3/body/conv2/
#                                                                  features/stage4/unit3/body/conv2/
#                                                                  features/stage4/unit3/body/conv2/
#                                                                  features/stage4/unit3/body/conv2/
#                                                                  features/stage4/unit3/body/conv2/
#                                                                  features/stage4/unit3/body/conv2/
#                                                                  features/stage4/unit3/body/conv2/
#                                                                  features/stage4/unit3/body/conv2/
#                                                                  features/stage4/unit3/body/conv2/
#                                                                  features/stage4/unit3/body/conv2/
#                                                                  features/stage4/unit3/body/conv2/
#                                                                  features/stage4/unit3/body/conv2/
#                                                                  features/stage4/unit3/body/conv2/
#                                                                  features/stage4/unit3/body/conv2/
#                                                                  features/stage4/unit3/body/conv2/
#                                                                  features/stage4/unit3/body/conv2/
#                                                                  features/stage4/unit3/body/conv2/
#                                                                  features/stage4/unit3/body/conv2/
#                                                                  features/stage4/unit3/body/conv2/
#                                                                  features/stage4/unit3/body/conv2/
#                                                                  features/stage4/unit3/body/conv2/
#                                                                  features/stage4/unit3/body/conv2/
#                                                                  features/stage4/unit3/body/conv2/
#                                                                  features/stage4/unit3/body/conv2/
# __________________________________________________________________________________________________
# features/stage4/unit3/body/conv (None, 7, 7, 1024)   4096        features/stage4/unit3/body/conv2/
# __________________________________________________________________________________________________
# features/stage4/unit3/body/conv (None, 7, 7, 1024)   0           features/stage4/unit3/body/conv2/
# __________________________________________________________________________________________________
# features/stage4/unit3/body/conv (None, 7, 7, 2048)   2097152     features/stage4/unit3/body/conv2/
# __________________________________________________________________________________________________
# features/stage4/unit3/body/conv (None, 7, 7, 2048)   8192        features/stage4/unit3/body/conv3/
# __________________________________________________________________________________________________
# features/stage4/unit3/se/pool ( (None, 1, 1, 2048)   0           features/stage4/unit3/body/conv3/
# __________________________________________________________________________________________________
# features/stage4/unit3/se/conv1  (None, 1, 1, 128)    262272      features/stage4/unit3/se/pool[0][
# __________________________________________________________________________________________________
# features/stage4/unit3/se/relu ( (None, 1, 1, 128)    0           features/stage4/unit3/se/conv1[0]
# __________________________________________________________________________________________________
# features/stage4/unit3/se/conv2  (None, 1, 1, 2048)   264192      features/stage4/unit3/se/relu[0][
# __________________________________________________________________________________________________
# features/stage4/unit3/se/sigmoi (None, 1, 1, 2048)   0           features/stage4/unit3/se/conv2[0]
# __________________________________________________________________________________________________
# features/stage4/unit3/se/mul (M (None, 7, 7, 2048)   0           features/stage4/unit3/body/conv3/
#                                                                  features/stage4/unit3/se/sigmoid[
# __________________________________________________________________________________________________
# features/stage4/unit3/add (Add) (None, 7, 7, 2048)   0           features/stage4/unit3/se/mul[0][0
#                                                                  features/stage4/unit2/activ[0][0]
# __________________________________________________________________________________________________
# features/stage4/unit3/activ (Ac (None, 7, 7, 2048)   0           features/stage4/unit3/add[0][0]
# __________________________________________________________________________________________________
# features/final_pool (AveragePoo (None, 1, 1, 2048)   0           features/stage4/unit3/activ[0][0]
# __________________________________________________________________________________________________
# lambda_1092 (Lambda)            (None, 2048)         0           features/final_pool[0][0]
# ==================================================================================================
# Total params: 47,044,272
# Trainable params: 46,906,416
# Non-trainable params: 137,856
# __________________________________________________________________________________________________

# %% [markdown]
# Replace the dense layer with a dense layer with 5 units for 5 classes (for example)

# %%
from keras.layers import Activation, Dense, Dropout

x = model.output
output = Dense(5)(x)
output = Activation('softmax')(output)

model = Model(
    inputs = base_model.input,
    outputs = output)

model.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 224, 224, 3)  0
# __________________________________________________________________________________________________
# lambda_1 (Lambda)               (None, 230, 230, 3)  0           input_1[0][0]
# __________________________________________________________________________________________________
# features/init_block/conv/conv ( (None, 112, 112, 64) 9408        lambda_1[0][0]
# __________________________________________________________________________________________________
# features/init_block/conv/bn (Ba (None, 112, 112, 64) 256         features/init_block/conv/conv[0][
# __________________________________________________________________________________________________
# features/init_block/conv/activ  (None, 112, 112, 64) 0           features/init_block/conv/bn[0][0]
# __________________________________________________________________________________________________
# lambda_2 (Lambda)               (None, 114, 114, 64) 0           features/init_block/conv/activ[0]
# __________________________________________________________________________________________________
# features/init_block/pool/pool ( (None, 56, 56, 64)   0           lambda_2[0][0]
# __________________________________________________________________________________________________
# features/stage1/unit1/body/conv (None, 56, 56, 128)  8192        features/init_block/pool/pool[0][
# __________________________________________________________________________________________________
# features/stage1/unit1/body/conv (None, 56, 56, 128)  512         features/stage1/unit1/body/conv1/
# __________________________________________________________________________________________________
# features/stage1/unit1/body/conv (None, 56, 56, 128)  0           features/stage1/unit1/body/conv1/
# __________________________________________________________________________________________________
# lambda_3 (Lambda)               (None, 58, 58, 128)  0           features/stage1/unit1/body/conv1/
# __________________________________________________________________________________________________
# lambda_4 (Lambda)               (None, 58, 58, 4)    0           lambda_3[0][0]
# __________________________________________________________________________________________________
# lambda_5 (Lambda)               (None, 58, 58, 4)    0           lambda_3[0][0]
# __________________________________________________________________________________________________
# lambda_6 (Lambda)               (None, 58, 58, 4)    0           lambda_3[0][0]
# __________________________________________________________________________________________________
# lambda_7 (Lambda)               (None, 58, 58, 4)    0           lambda_3[0][0]
# __________________________________________________________________________________________________
# lambda_8 (Lambda)               (None, 58, 58, 4)    0           lambda_3[0][0]
# __________________________________________________________________________________________________
# lambda_9 (Lambda)               (None, 58, 58, 4)    0           lambda_3[0][0]
# __________________________________________________________________________________________________
# lambda_10 (Lambda)              (None, 58, 58, 4)    0           lambda_3[0][0]
# __________________________________________________________________________________________________
# lambda_11 (Lambda)              (None, 58, 58, 4)    0           lambda_3[0][0]
# __________________________________________________________________________________________________
# lambda_12 (Lambda)              (None, 58, 58, 4)    0           lambda_3[0][0]
# __________________________________________________________________________________________________
# lambda_13 (Lambda)              (None, 58, 58, 4)    0           lambda_3[0][0]
# __________________________________________________________________________________________________
# lambda_14 (Lambda)              (None, 58, 58, 4)    0           lambda_3[0][0]
# __________________________________________________________________________________________________
# lambda_15 (Lambda)              (None, 58, 58, 4)    0           lambda_3[0][0]
# __________________________________________________________________________________________________
# lambda_16 (Lambda)              (None, 58, 58, 4)    0           lambda_3[0][0]
# __________________________________________________________________________________________________
# lambda_17 (Lambda)              (None, 58, 58, 4)    0           lambda_3[0][0]
# __________________________________________________________________________________________________
# lambda_18 (Lambda)              (None, 58, 58, 4)    0           lambda_3[0][0]
# __________________________________________________________________________________________________
# lambda_19 (Lambda)              (None, 58, 58, 4)    0           lambda_3[0][0]
# __________________________________________________________________________________________________
# lambda_20 (Lambda)              (None, 58, 58, 4)    0           lambda_3[0][0]
# __________________________________________________________________________________________________
# lambda_21 (Lambda)              (None, 58, 58, 4)    0           lambda_3[0][0]
# __________________________________________________________________________________________________
# lambda_22 (Lambda)              (None, 58, 58, 4)    0           lambda_3[0][0]
# __________________________________________________________________________________________________
# lambda_23 (Lambda)              (None, 58, 58, 4)    0           lambda_3[0][0]
# __________________________________________________________________________________________________
# lambda_24 (Lambda)              (None, 58, 58, 4)    0           lambda_3[0][0]
# __________________________________________________________________________________________________
# lambda_25 (Lambda)              (None, 58, 58, 4)    0           lambda_3[0][0]
# __________________________________________________________________________________________________
# lambda_26 (Lambda)              (None, 58, 58, 4)    0           lambda_3[0][0]
# __________________________________________________________________________________________________
# lambda_27 (Lambda)              (None, 58, 58, 4)    0           lambda_3[0][0]
# __________________________________________________________________________________________________
# lambda_28 (Lambda)              (None, 58, 58, 4)    0           lambda_3[0][0]
# __________________________________________________________________________________________________
# lambda_29 (Lambda)              (None, 58, 58, 4)    0           lambda_3[0][0]
# __________________________________________________________________________________________________
# lambda_30 (Lambda)              (None, 58, 58, 4)    0           lambda_3[0][0]
# __________________________________________________________________________________________________
# lambda_31 (Lambda)              (None, 58, 58, 4)    0           lambda_3[0][0]
# __________________________________________________________________________________________________
# lambda_32 (Lambda)              (None, 58, 58, 4)    0           lambda_3[0][0]
# __________________________________________________________________________________________________
# lambda_33 (Lambda)              (None, 58, 58, 4)    0           lambda_3[0][0]
# __________________________________________________________________________________________________
# lambda_34 (Lambda)              (None, 58, 58, 4)    0           lambda_3[0][0]
# __________________________________________________________________________________________________
# lambda_35 (Lambda)              (None, 58, 58, 4)    0           lambda_3[0][0]
# __________________________________________________________________________________________________
# features/stage1/unit1/body/conv (None, 56, 56, 4)    144         lambda_4[0][0]
# __________________________________________________________________________________________________
# features/stage1/unit1/body/conv (None, 56, 56, 4)    144         lambda_5[0][0]
# __________________________________________________________________________________________________
# features/stage1/unit1/body/conv (None, 56, 56, 4)    144         lambda_6[0][0]
# __________________________________________________________________________________________________
# features/stage1/unit1/body/conv (None, 56, 56, 4)    144         lambda_7[0][0]
# __________________________________________________________________________________________________
# features/stage1/unit1/body/conv (None, 56, 56, 4)    144         lambda_8[0][0]
# __________________________________________________________________________________________________
# features/stage1/unit1/body/conv (None, 56, 56, 4)    144         lambda_9[0][0]
# __________________________________________________________________________________________________
# features/stage1/unit1/body/conv (None, 56, 56, 4)    144         lambda_10[0][0]
# __________________________________________________________________________________________________
# features/stage1/unit1/body/conv (None, 56, 56, 4)    144         lambda_11[0][0]
# __________________________________________________________________________________________________
# features/stage1/unit1/body/conv (None, 56, 56, 4)    144         lambda_12[0][0]
# __________________________________________________________________________________________________
# features/stage1/unit1/body/conv (None, 56, 56, 4)    144         lambda_13[0][0]
# __________________________________________________________________________________________________
# features/stage1/unit1/body/conv (None, 56, 56, 4)    144         lambda_14[0][0]
# __________________________________________________________________________________________________
# features/stage1/unit1/body/conv (None, 56, 56, 4)    144         lambda_15[0][0]
# __________________________________________________________________________________________________
# features/stage1/unit1/body/conv (None, 56, 56, 4)    144         lambda_16[0][0]
# __________________________________________________________________________________________________
# features/stage1/unit1/body/conv (None, 56, 56, 4)    144         lambda_17[0][0]
# __________________________________________________________________________________________________
# features/stage1/unit1/body/conv (None, 56, 56, 4)    144         lambda_18[0][0]
# __________________________________________________________________________________________________
# features/stage1/unit1/body/conv (None, 56, 56, 4)    144         lambda_19[0][0]
# __________________________________________________________________________________________________
# features/stage1/unit1/body/conv (None, 56, 56, 4)    144         lambda_20[0][0]
# __________________________________________________________________________________________________
# features/stage1/unit1/body/conv (None, 56, 56, 4)    144         lambda_21[0][0]
# __________________________________________________________________________________________________
# features/stage1/unit1/body/conv (None, 56, 56, 4)    144         lambda_22[0][0]
# __________________________________________________________________________________________________
# features/stage1/unit1/body/conv (None, 56, 56, 4)    144         lambda_23[0][0]
# __________________________________________________________________________________________________
# features/stage1/unit1/body/conv (None, 56, 56, 4)    144         lambda_24[0][0]
# __________________________________________________________________________________________________
# features/stage1/unit1/body/conv (None, 56, 56, 4)    144         lambda_25[0][0]
# __________________________________________________________________________________________________
# features/stage1/unit1/body/conv (None, 56, 56, 4)    144         lambda_26[0][0]
# __________________________________________________________________________________________________
# features/stage1/unit1/body/conv (None, 56, 56, 4)    144         lambda_27[0][0]
# __________________________________________________________________________________________________
# features/stage1/unit1/body/conv (None, 56, 56, 4)    144         lambda_28[0][0]
# __________________________________________________________________________________________________
# features/stage1/unit1/body/conv (None, 56, 56, 4)    144         lambda_29[0][0]
# __________________________________________________________________________________________________
# features/stage1/unit1/body/conv (None, 56, 56, 4)    144         lambda_30[0][0]
# __________________________________________________________________________________________________
# features/stage1/unit1/body/conv (None, 56, 56, 4)    144         lambda_31[0][0]
# __________________________________________________________________________________________________
# features/stage1/unit1/body/conv (None, 56, 56, 4)    144         lambda_32[0][0]
# __________________________________________________________________________________________________
# features/stage1/unit1/body/conv (None, 56, 56, 4)    144         lambda_33[0][0]
# __________________________________________________________________________________________________
# features/stage1/unit1/body/conv (None, 56, 56, 4)    144         lambda_34[0][0]
# __________________________________________________________________________________________________
# features/stage1/unit1/body/conv (None, 56, 56, 4)    144         lambda_35[0][0]
# __________________________________________________________________________________________________
# features/stage1/unit1/body/conv (None, 56, 56, 128)  0           features/stage1/unit1/body/conv2/
#                                                                  features/stage1/unit1/body/conv2/
#                                                                  features/stage1/unit1/body/conv2/
#                                                                  features/stage1/unit1/body/conv2/
#                                                                  features/stage1/unit1/body/conv2/
#                                                                  features/stage1/unit1/body/conv2/
#                                                                  features/stage1/unit1/body/conv2/
#                                                                  features/stage1/unit1/body/conv2/
#                                                                  features/stage1/unit1/body/conv2/
#                                                                  features/stage1/unit1/body/conv2/
#                                                                  features/stage1/unit1/body/conv2/
#                                                                  features/stage1/unit1/body/conv2/
#                                                                  features/stage1/unit1/body/conv2/
#                                                                  features/stage1/unit1/body/conv2/
#                                                                  features/stage1/unit1/body/conv2/
#                                                                  features/stage1/unit1/body/conv2/
#                                                                  features/stage1/unit1/body/conv2/
#                                                                  features/stage1/unit1/body/conv2/
#                                                                  features/stage1/unit1/body/conv2/
#                                                                  features/stage1/unit1/body/conv2/
#                                                                  features/stage1/unit1/body/conv2/
#                                                                  features/stage1/unit1/body/conv2/
#                                                                  features/stage1/unit1/body/conv2/
#                                                                  features/stage1/unit1/body/conv2/
#                                                                  features/stage1/unit1/body/conv2/
#                                                                  features/stage1/unit1/body/conv2/
#                                                                  features/stage1/unit1/body/conv2/
#                                                                  features/stage1/unit1/body/conv2/
#                                                                  features/stage1/unit1/body/conv2/
#                                                                  features/stage1/unit1/body/conv2/
#                                                                  features/stage1/unit1/body/conv2/
#                                                                  features/stage1/unit1/body/conv2/
# __________________________________________________________________________________________________
# features/stage1/unit1/body/conv (None, 56, 56, 128)  512         features/stage1/unit1/body/conv2/
# __________________________________________________________________________________________________
# features/stage1/unit1/body/conv (None, 56, 56, 128)  0           features/stage1/unit1/body/conv2/
# __________________________________________________________________________________________________
# features/stage1/unit1/body/conv (None, 56, 56, 256)  32768       features/stage1/unit1/body/conv2/
# __________________________________________________________________________________________________
# features/stage1/unit1/body/conv (None, 56, 56, 256)  1024        features/stage1/unit1/body/conv3/
# __________________________________________________________________________________________________
# features/stage1/unit1/se/pool ( (None, 1, 1, 256)    0           features/stage1/unit1/body/conv3/
# __________________________________________________________________________________________________
# features/stage1/unit1/se/conv1  (None, 1, 1, 16)     4112        features/stage1/unit1/se/pool[0][
# __________________________________________________________________________________________________
# features/stage1/unit1/se/relu ( (None, 1, 1, 16)     0           features/stage1/unit1/se/conv1[0]
# __________________________________________________________________________________________________
# features/stage1/unit1/se/conv2  (None, 1, 1, 256)    4352        features/stage1/unit1/se/relu[0][
# __________________________________________________________________________________________________
# features/stage1/unit1/se/sigmoi (None, 1, 1, 256)    0           features/stage1/unit1/se/conv2[0]
# __________________________________________________________________________________________________
# features/stage1/unit1/identity_ (None, 56, 56, 256)  16384       features/init_block/pool/pool[0][
# __________________________________________________________________________________________________
# features/stage1/unit1/se/mul (M (None, 56, 56, 256)  0           features/stage1/unit1/body/conv3/
#                                                                  features/stage1/unit1/se/sigmoid[
# __________________________________________________________________________________________________
# features/stage1/unit1/identity_ (None, 56, 56, 256)  1024        features/stage1/unit1/identity_co
# __________________________________________________________________________________________________
# features/stage1/unit1/add (Add) (None, 56, 56, 256)  0           features/stage1/unit1/se/mul[0][0
#                                                                  features/stage1/unit1/identity_co
# __________________________________________________________________________________________________
# features/stage1/unit1/activ (Ac (None, 56, 56, 256)  0           features/stage1/unit1/add[0][0]
# __________________________________________________________________________________________________
# features/stage1/unit2/body/conv (None, 56, 56, 128)  32768       features/stage1/unit1/activ[0][0]
# __________________________________________________________________________________________________
# features/stage1/unit2/body/conv (None, 56, 56, 128)  512         features/stage1/unit2/body/conv1/
# __________________________________________________________________________________________________
# features/stage1/unit2/body/conv (None, 56, 56, 128)  0           features/stage1/unit2/body/conv1/
# __________________________________________________________________________________________________
# lambda_36 (Lambda)              (None, 58, 58, 128)  0           features/stage1/unit2/body/conv1/
# __________________________________________________________________________________________________
# lambda_37 (Lambda)              (None, 58, 58, 4)    0           lambda_36[0][0]
# __________________________________________________________________________________________________
# lambda_38 (Lambda)              (None, 58, 58, 4)    0           lambda_36[0][0]
# __________________________________________________________________________________________________
# lambda_39 (Lambda)              (None, 58, 58, 4)    0           lambda_36[0][0]
# __________________________________________________________________________________________________
# lambda_40 (Lambda)              (None, 58, 58, 4)    0           lambda_36[0][0]
# __________________________________________________________________________________________________
# lambda_41 (Lambda)              (None, 58, 58, 4)    0           lambda_36[0][0]
# __________________________________________________________________________________________________
# lambda_42 (Lambda)              (None, 58, 58, 4)    0           lambda_36[0][0]
# __________________________________________________________________________________________________
# lambda_43 (Lambda)              (None, 58, 58, 4)    0           lambda_36[0][0]
# __________________________________________________________________________________________________
# lambda_44 (Lambda)              (None, 58, 58, 4)    0           lambda_36[0][0]
# __________________________________________________________________________________________________
# lambda_45 (Lambda)              (None, 58, 58, 4)    0           lambda_36[0][0]
# __________________________________________________________________________________________________
# lambda_46 (Lambda)              (None, 58, 58, 4)    0           lambda_36[0][0]
# __________________________________________________________________________________________________
# lambda_47 (Lambda)              (None, 58, 58, 4)    0           lambda_36[0][0]
# __________________________________________________________________________________________________
# lambda_48 (Lambda)              (None, 58, 58, 4)    0           lambda_36[0][0]
# __________________________________________________________________________________________________
# lambda_49 (Lambda)              (None, 58, 58, 4)    0           lambda_36[0][0]
# __________________________________________________________________________________________________
# lambda_50 (Lambda)              (None, 58, 58, 4)    0           lambda_36[0][0]
# __________________________________________________________________________________________________
# lambda_51 (Lambda)              (None, 58, 58, 4)    0           lambda_36[0][0]
# __________________________________________________________________________________________________
# lambda_52 (Lambda)              (None, 58, 58, 4)    0           lambda_36[0][0]
# __________________________________________________________________________________________________
# lambda_53 (Lambda)              (None, 58, 58, 4)    0           lambda_36[0][0]
# __________________________________________________________________________________________________
# lambda_54 (Lambda)              (None, 58, 58, 4)    0           lambda_36[0][0]
# __________________________________________________________________________________________________
# lambda_55 (Lambda)              (None, 58, 58, 4)    0           lambda_36[0][0]
# __________________________________________________________________________________________________
# lambda_56 (Lambda)              (None, 58, 58, 4)    0           lambda_36[0][0]
# __________________________________________________________________________________________________
# lambda_57 (Lambda)              (None, 58, 58, 4)    0           lambda_36[0][0]
# __________________________________________________________________________________________________
# lambda_58 (Lambda)              (None, 58, 58, 4)    0           lambda_36[0][0]
# __________________________________________________________________________________________________
# lambda_59 (Lambda)              (None, 58, 58, 4)    0           lambda_36[0][0]
# __________________________________________________________________________________________________
# lambda_60 (Lambda)              (None, 58, 58, 4)    0           lambda_36[0][0]
# __________________________________________________________________________________________________
# lambda_61 (Lambda)              (None, 58, 58, 4)    0           lambda_36[0][0]
# __________________________________________________________________________________________________
# lambda_62 (Lambda)              (None, 58, 58, 4)    0           lambda_36[0][0]
# __________________________________________________________________________________________________
# lambda_63 (Lambda)              (None, 58, 58, 4)    0           lambda_36[0][0]
# __________________________________________________________________________________________________
# lambda_64 (Lambda)              (None, 58, 58, 4)    0           lambda_36[0][0]
# __________________________________________________________________________________________________
# lambda_65 (Lambda)              (None, 58, 58, 4)    0           lambda_36[0][0]
# __________________________________________________________________________________________________
# lambda_66 (Lambda)              (None, 58, 58, 4)    0           lambda_36[0][0]
# __________________________________________________________________________________________________
# lambda_67 (Lambda)              (None, 58, 58, 4)    0           lambda_36[0][0]
# __________________________________________________________________________________________________
# lambda_68 (Lambda)              (None, 58, 58, 4)    0           lambda_36[0][0]
# __________________________________________________________________________________________________
# features/stage1/unit2/body/conv (None, 56, 56, 4)    144         lambda_37[0][0]
# __________________________________________________________________________________________________
# features/stage1/unit2/body/conv (None, 56, 56, 4)    144         lambda_38[0][0]
# __________________________________________________________________________________________________
# features/stage1/unit2/body/conv (None, 56, 56, 4)    144         lambda_39[0][0]
# __________________________________________________________________________________________________
# features/stage1/unit2/body/conv (None, 56, 56, 4)    144         lambda_40[0][0]
# __________________________________________________________________________________________________
# features/stage1/unit2/body/conv (None, 56, 56, 4)    144         lambda_41[0][0]
# __________________________________________________________________________________________________
# features/stage1/unit2/body/conv (None, 56, 56, 4)    144         lambda_42[0][0]
# __________________________________________________________________________________________________
# features/stage1/unit2/body/conv (None, 56, 56, 4)    144         lambda_43[0][0]
# __________________________________________________________________________________________________
# features/stage1/unit2/body/conv (None, 56, 56, 4)    144         lambda_44[0][0]
# __________________________________________________________________________________________________
# features/stage1/unit2/body/conv (None, 56, 56, 4)    144         lambda_45[0][0]
# __________________________________________________________________________________________________
# features/stage1/unit2/body/conv (None, 56, 56, 4)    144         lambda_46[0][0]
# __________________________________________________________________________________________________
# features/stage1/unit2/body/conv (None, 56, 56, 4)    144         lambda_47[0][0]
# __________________________________________________________________________________________________
# features/stage1/unit2/body/conv (None, 56, 56, 4)    144         lambda_48[0][0]
# __________________________________________________________________________________________________
# features/stage1/unit2/body/conv (None, 56, 56, 4)    144         lambda_49[0][0]
# __________________________________________________________________________________________________
# features/stage1/unit2/body/conv (None, 56, 56, 4)    144         lambda_50[0][0]
# __________________________________________________________________________________________________
# features/stage1/unit2/body/conv (None, 56, 56, 4)    144         lambda_51[0][0]
# __________________________________________________________________________________________________
# features/stage1/unit2/body/conv (None, 56, 56, 4)    144         lambda_52[0][0]
# __________________________________________________________________________________________________
# features/stage1/unit2/body/conv (None, 56, 56, 4)    144         lambda_53[0][0]
# __________________________________________________________________________________________________
# features/stage1/unit2/body/conv (None, 56, 56, 4)    144         lambda_54[0][0]
# __________________________________________________________________________________________________
# features/stage1/unit2/body/conv (None, 56, 56, 4)    144         lambda_55[0][0]
# __________________________________________________________________________________________________
# features/stage1/unit2/body/conv (None, 56, 56, 4)    144         lambda_56[0][0]
# __________________________________________________________________________________________________
# features/stage1/unit2/body/conv (None, 56, 56, 4)    144         lambda_57[0][0]
# __________________________________________________________________________________________________
# features/stage1/unit2/body/conv (None, 56, 56, 4)    144         lambda_58[0][0]
# __________________________________________________________________________________________________
# features/stage1/unit2/body/conv (None, 56, 56, 4)    144         lambda_59[0][0]
# __________________________________________________________________________________________________
# features/stage1/unit2/body/conv (None, 56, 56, 4)    144         lambda_60[0][0]
# __________________________________________________________________________________________________
# features/stage1/unit2/body/conv (None, 56, 56, 4)    144         lambda_61[0][0]
# __________________________________________________________________________________________________
# features/stage1/unit2/body/conv (None, 56, 56, 4)    144         lambda_62[0][0]
# __________________________________________________________________________________________________
# features/stage1/unit2/body/conv (None, 56, 56, 4)    144         lambda_63[0][0]
# __________________________________________________________________________________________________
# features/stage1/unit2/body/conv (None, 56, 56, 4)    144         lambda_64[0][0]
# __________________________________________________________________________________________________
# features/stage1/unit2/body/conv (None, 56, 56, 4)    144         lambda_65[0][0]
# __________________________________________________________________________________________________
# features/stage1/unit2/body/conv (None, 56, 56, 4)    144         lambda_66[0][0]
# __________________________________________________________________________________________________
# features/stage1/unit2/body/conv (None, 56, 56, 4)    144         lambda_67[0][0]
# __________________________________________________________________________________________________
# features/stage1/unit2/body/conv (None, 56, 56, 4)    144         lambda_68[0][0]
# __________________________________________________________________________________________________
# features/stage1/unit2/body/conv (None, 56, 56, 128)  0           features/stage1/unit2/body/conv2/
#                                                                  features/stage1/unit2/body/conv2/
#                                                                  features/stage1/unit2/body/conv2/
#                                                                  features/stage1/unit2/body/conv2/
#                                                                  features/stage1/unit2/body/conv2/
#                                                                  features/stage1/unit2/body/conv2/
#                                                                  features/stage1/unit2/body/conv2/
#                                                                  features/stage1/unit2/body/conv2/
#                                                                  features/stage1/unit2/body/conv2/
#                                                                  features/stage1/unit2/body/conv2/
#                                                                  features/stage1/unit2/body/conv2/
#                                                                  features/stage1/unit2/body/conv2/
#                                                                  features/stage1/unit2/body/conv2/
#                                                                  features/stage1/unit2/body/conv2/
#                                                                  features/stage1/unit2/body/conv2/
#                                                                  features/stage1/unit2/body/conv2/
#                                                                  features/stage1/unit2/body/conv2/
#                                                                  features/stage1/unit2/body/conv2/
#                                                                  features/stage1/unit2/body/conv2/
#                                                                  features/stage1/unit2/body/conv2/
#                                                                  features/stage1/unit2/body/conv2/
#                                                                  features/stage1/unit2/body/conv2/
#                                                                  features/stage1/unit2/body/conv2/
#                                                                  features/stage1/unit2/body/conv2/
#                                                                  features/stage1/unit2/body/conv2/
#                                                                  features/stage1/unit2/body/conv2/
#                                                                  features/stage1/unit2/body/conv2/
#                                                                  features/stage1/unit2/body/conv2/
#                                                                  features/stage1/unit2/body/conv2/
#                                                                  features/stage1/unit2/body/conv2/
#                                                                  features/stage1/unit2/body/conv2/
#                                                                  features/stage1/unit2/body/conv2/
# __________________________________________________________________________________________________
# features/stage1/unit2/body/conv (None, 56, 56, 128)  512         features/stage1/unit2/body/conv2/
# __________________________________________________________________________________________________
# features/stage1/unit2/body/conv (None, 56, 56, 128)  0           features/stage1/unit2/body/conv2/
# __________________________________________________________________________________________________
# features/stage1/unit2/body/conv (None, 56, 56, 256)  32768       features/stage1/unit2/body/conv2/
# __________________________________________________________________________________________________
# features/stage1/unit2/body/conv (None, 56, 56, 256)  1024        features/stage1/unit2/body/conv3/
# __________________________________________________________________________________________________
# features/stage1/unit2/se/pool ( (None, 1, 1, 256)    0           features/stage1/unit2/body/conv3/
# __________________________________________________________________________________________________
# features/stage1/unit2/se/conv1  (None, 1, 1, 16)     4112        features/stage1/unit2/se/pool[0][
# __________________________________________________________________________________________________
# features/stage1/unit2/se/relu ( (None, 1, 1, 16)     0           features/stage1/unit2/se/conv1[0]
# __________________________________________________________________________________________________
# features/stage1/unit2/se/conv2  (None, 1, 1, 256)    4352        features/stage1/unit2/se/relu[0][
# __________________________________________________________________________________________________
# features/stage1/unit2/se/sigmoi (None, 1, 1, 256)    0           features/stage1/unit2/se/conv2[0]
# __________________________________________________________________________________________________
# features/stage1/unit2/se/mul (M (None, 56, 56, 256)  0           features/stage1/unit2/body/conv3/
#                                                                  features/stage1/unit2/se/sigmoid[
# __________________________________________________________________________________________________
# features/stage1/unit2/add (Add) (None, 56, 56, 256)  0           features/stage1/unit2/se/mul[0][0
#                                                                  features/stage1/unit1/activ[0][0]
# __________________________________________________________________________________________________
# features/stage1/unit2/activ (Ac (None, 56, 56, 256)  0           features/stage1/unit2/add[0][0]
# __________________________________________________________________________________________________
# features/stage1/unit3/body/conv (None, 56, 56, 128)  32768       features/stage1/unit2/activ[0][0]
# __________________________________________________________________________________________________
# features/stage1/unit3/body/conv (None, 56, 56, 128)  512         features/stage1/unit3/body/conv1/
# __________________________________________________________________________________________________
# features/stage1/unit3/body/conv (None, 56, 56, 128)  0           features/stage1/unit3/body/conv1/
# __________________________________________________________________________________________________
# lambda_69 (Lambda)              (None, 58, 58, 128)  0           features/stage1/unit3/body/conv1/
# __________________________________________________________________________________________________
# lambda_70 (Lambda)              (None, 58, 58, 4)    0           lambda_69[0][0]
# __________________________________________________________________________________________________
# lambda_71 (Lambda)              (None, 58, 58, 4)    0           lambda_69[0][0]
# __________________________________________________________________________________________________
# lambda_72 (Lambda)              (None, 58, 58, 4)    0           lambda_69[0][0]
# __________________________________________________________________________________________________
# lambda_73 (Lambda)              (None, 58, 58, 4)    0           lambda_69[0][0]
# __________________________________________________________________________________________________
# lambda_74 (Lambda)              (None, 58, 58, 4)    0           lambda_69[0][0]
# __________________________________________________________________________________________________
# lambda_75 (Lambda)              (None, 58, 58, 4)    0           lambda_69[0][0]
# __________________________________________________________________________________________________
# lambda_76 (Lambda)              (None, 58, 58, 4)    0           lambda_69[0][0]
# __________________________________________________________________________________________________
# lambda_77 (Lambda)              (None, 58, 58, 4)    0           lambda_69[0][0]
# __________________________________________________________________________________________________
# lambda_78 (Lambda)              (None, 58, 58, 4)    0           lambda_69[0][0]
# __________________________________________________________________________________________________
# lambda_79 (Lambda)              (None, 58, 58, 4)    0           lambda_69[0][0]
# __________________________________________________________________________________________________
# lambda_80 (Lambda)              (None, 58, 58, 4)    0           lambda_69[0][0]
# __________________________________________________________________________________________________
# lambda_81 (Lambda)              (None, 58, 58, 4)    0           lambda_69[0][0]
# __________________________________________________________________________________________________
# lambda_82 (Lambda)              (None, 58, 58, 4)    0           lambda_69[0][0]
# __________________________________________________________________________________________________
# lambda_83 (Lambda)              (None, 58, 58, 4)    0           lambda_69[0][0]
# __________________________________________________________________________________________________
# lambda_84 (Lambda)              (None, 58, 58, 4)    0           lambda_69[0][0]
# __________________________________________________________________________________________________
# lambda_85 (Lambda)              (None, 58, 58, 4)    0           lambda_69[0][0]
# __________________________________________________________________________________________________
# lambda_86 (Lambda)              (None, 58, 58, 4)    0           lambda_69[0][0]
# __________________________________________________________________________________________________
# lambda_87 (Lambda)              (None, 58, 58, 4)    0           lambda_69[0][0]
# __________________________________________________________________________________________________
# lambda_88 (Lambda)              (None, 58, 58, 4)    0           lambda_69[0][0]
# __________________________________________________________________________________________________
# lambda_89 (Lambda)              (None, 58, 58, 4)    0           lambda_69[0][0]
# __________________________________________________________________________________________________
# lambda_90 (Lambda)              (None, 58, 58, 4)    0           lambda_69[0][0]
# __________________________________________________________________________________________________
# lambda_91 (Lambda)              (None, 58, 58, 4)    0           lambda_69[0][0]
# __________________________________________________________________________________________________
# lambda_92 (Lambda)              (None, 58, 58, 4)    0           lambda_69[0][0]
# __________________________________________________________________________________________________
# lambda_93 (Lambda)              (None, 58, 58, 4)    0           lambda_69[0][0]
# __________________________________________________________________________________________________
# lambda_94 (Lambda)              (None, 58, 58, 4)    0           lambda_69[0][0]
# __________________________________________________________________________________________________
# lambda_95 (Lambda)              (None, 58, 58, 4)    0           lambda_69[0][0]
# __________________________________________________________________________________________________
# lambda_96 (Lambda)              (None, 58, 58, 4)    0           lambda_69[0][0]
# __________________________________________________________________________________________________
# lambda_97 (Lambda)              (None, 58, 58, 4)    0           lambda_69[0][0]
# __________________________________________________________________________________________________
# lambda_98 (Lambda)              (None, 58, 58, 4)    0           lambda_69[0][0]
# __________________________________________________________________________________________________
# lambda_99 (Lambda)              (None, 58, 58, 4)    0           lambda_69[0][0]
# __________________________________________________________________________________________________
# lambda_100 (Lambda)             (None, 58, 58, 4)    0           lambda_69[0][0]
# __________________________________________________________________________________________________
# lambda_101 (Lambda)             (None, 58, 58, 4)    0           lambda_69[0][0]
# __________________________________________________________________________________________________
# features/stage1/unit3/body/conv (None, 56, 56, 4)    144         lambda_70[0][0]
# ...
# lambda_1078 (Lambda)            (None, 9, 9, 32)     0           lambda_1059[0][0]
# __________________________________________________________________________________________________
# lambda_1079 (Lambda)            (None, 9, 9, 32)     0           lambda_1059[0][0]
# __________________________________________________________________________________________________
# lambda_1080 (Lambda)            (None, 9, 9, 32)     0           lambda_1059[0][0]
# __________________________________________________________________________________________________
# lambda_1081 (Lambda)            (None, 9, 9, 32)     0           lambda_1059[0][0]
# __________________________________________________________________________________________________
# lambda_1082 (Lambda)            (None, 9, 9, 32)     0           lambda_1059[0][0]
# __________________________________________________________________________________________________
# lambda_1083 (Lambda)            (None, 9, 9, 32)     0           lambda_1059[0][0]
# __________________________________________________________________________________________________
# lambda_1084 (Lambda)            (None, 9, 9, 32)     0           lambda_1059[0][0]
# __________________________________________________________________________________________________
# lambda_1085 (Lambda)            (None, 9, 9, 32)     0           lambda_1059[0][0]
# __________________________________________________________________________________________________
# lambda_1086 (Lambda)            (None, 9, 9, 32)     0           lambda_1059[0][0]
# __________________________________________________________________________________________________
# lambda_1087 (Lambda)            (None, 9, 9, 32)     0           lambda_1059[0][0]
# __________________________________________________________________________________________________
# lambda_1088 (Lambda)            (None, 9, 9, 32)     0           lambda_1059[0][0]
# __________________________________________________________________________________________________
# lambda_1089 (Lambda)            (None, 9, 9, 32)     0           lambda_1059[0][0]
# __________________________________________________________________________________________________
# lambda_1090 (Lambda)            (None, 9, 9, 32)     0           lambda_1059[0][0]
# __________________________________________________________________________________________________
# lambda_1091 (Lambda)            (None, 9, 9, 32)     0           lambda_1059[0][0]
# __________________________________________________________________________________________________
# features/stage4/unit3/body/conv (None, 7, 7, 32)     9216        lambda_1060[0][0]
# __________________________________________________________________________________________________
# features/stage4/unit3/body/conv (None, 7, 7, 32)     9216        lambda_1061[0][0]
# __________________________________________________________________________________________________
# features/stage4/unit3/body/conv (None, 7, 7, 32)     9216        lambda_1062[0][0]
# __________________________________________________________________________________________________
# features/stage4/unit3/body/conv (None, 7, 7, 32)     9216        lambda_1063[0][0]
# __________________________________________________________________________________________________
# features/stage4/unit3/body/conv (None, 7, 7, 32)     9216        lambda_1064[0][0]
# __________________________________________________________________________________________________
# features/stage4/unit3/body/conv (None, 7, 7, 32)     9216        lambda_1065[0][0]
# __________________________________________________________________________________________________
# features/stage4/unit3/body/conv (None, 7, 7, 32)     9216        lambda_1066[0][0]
# __________________________________________________________________________________________________
# features/stage4/unit3/body/conv (None, 7, 7, 32)     9216        lambda_1067[0][0]
# __________________________________________________________________________________________________
# features/stage4/unit3/body/conv (None, 7, 7, 32)     9216        lambda_1068[0][0]
# __________________________________________________________________________________________________
# features/stage4/unit3/body/conv (None, 7, 7, 32)     9216        lambda_1069[0][0]
# __________________________________________________________________________________________________
# features/stage4/unit3/body/conv (None, 7, 7, 32)     9216        lambda_1070[0][0]
# __________________________________________________________________________________________________
# features/stage4/unit3/body/conv (None, 7, 7, 32)     9216        lambda_1071[0][0]
# __________________________________________________________________________________________________
# features/stage4/unit3/body/conv (None, 7, 7, 32)     9216        lambda_1072[0][0]
# __________________________________________________________________________________________________
# features/stage4/unit3/body/conv (None, 7, 7, 32)     9216        lambda_1073[0][0]
# __________________________________________________________________________________________________
# features/stage4/unit3/body/conv (None, 7, 7, 32)     9216        lambda_1074[0][0]
# __________________________________________________________________________________________________
# features/stage4/unit3/body/conv (None, 7, 7, 32)     9216        lambda_1075[0][0]
# __________________________________________________________________________________________________
# features/stage4/unit3/body/conv (None, 7, 7, 32)     9216        lambda_1076[0][0]
# __________________________________________________________________________________________________
# features/stage4/unit3/body/conv (None, 7, 7, 32)     9216        lambda_1077[0][0]
# __________________________________________________________________________________________________
# features/stage4/unit3/body/conv (None, 7, 7, 32)     9216        lambda_1078[0][0]
# __________________________________________________________________________________________________
# features/stage4/unit3/body/conv (None, 7, 7, 32)     9216        lambda_1079[0][0]
# __________________________________________________________________________________________________
# features/stage4/unit3/body/conv (None, 7, 7, 32)     9216        lambda_1080[0][0]
# __________________________________________________________________________________________________
# features/stage4/unit3/body/conv (None, 7, 7, 32)     9216        lambda_1081[0][0]
# __________________________________________________________________________________________________
# features/stage4/unit3/body/conv (None, 7, 7, 32)     9216        lambda_1082[0][0]
# __________________________________________________________________________________________________
# features/stage4/unit3/body/conv (None, 7, 7, 32)     9216        lambda_1083[0][0]
# __________________________________________________________________________________________________
# features/stage4/unit3/body/conv (None, 7, 7, 32)     9216        lambda_1084[0][0]
# __________________________________________________________________________________________________
# features/stage4/unit3/body/conv (None, 7, 7, 32)     9216        lambda_1085[0][0]
# __________________________________________________________________________________________________
# features/stage4/unit3/body/conv (None, 7, 7, 32)     9216        lambda_1086[0][0]
# __________________________________________________________________________________________________
# features/stage4/unit3/body/conv (None, 7, 7, 32)     9216        lambda_1087[0][0]
# __________________________________________________________________________________________________
# features/stage4/unit3/body/conv (None, 7, 7, 32)     9216        lambda_1088[0][0]
# __________________________________________________________________________________________________
# features/stage4/unit3/body/conv (None, 7, 7, 32)     9216        lambda_1089[0][0]
# __________________________________________________________________________________________________
# features/stage4/unit3/body/conv (None, 7, 7, 32)     9216        lambda_1090[0][0]
# __________________________________________________________________________________________________
# features/stage4/unit3/body/conv (None, 7, 7, 32)     9216        lambda_1091[0][0]
# __________________________________________________________________________________________________
# features/stage4/unit3/body/conv (None, 7, 7, 1024)   0           features/stage4/unit3/body/conv2/
#                                                                  features/stage4/unit3/body/conv2/
#                                                                  features/stage4/unit3/body/conv2/
#                                                                  features/stage4/unit3/body/conv2/
#                                                                  features/stage4/unit3/body/conv2/
#                                                                  features/stage4/unit3/body/conv2/
#                                                                  features/stage4/unit3/body/conv2/
#                                                                  features/stage4/unit3/body/conv2/
#                                                                  features/stage4/unit3/body/conv2/
#                                                                  features/stage4/unit3/body/conv2/
#                                                                  features/stage4/unit3/body/conv2/
#                                                                  features/stage4/unit3/body/conv2/
#                                                                  features/stage4/unit3/body/conv2/
#                                                                  features/stage4/unit3/body/conv2/
#                                                                  features/stage4/unit3/body/conv2/
#                                                                  features/stage4/unit3/body/conv2/
#                                                                  features/stage4/unit3/body/conv2/
#                                                                  features/stage4/unit3/body/conv2/
#                                                                  features/stage4/unit3/body/conv2/
#                                                                  features/stage4/unit3/body/conv2/
#                                                                  features/stage4/unit3/body/conv2/
#                                                                  features/stage4/unit3/body/conv2/
#                                                                  features/stage4/unit3/body/conv2/
#                                                                  features/stage4/unit3/body/conv2/
#                                                                  features/stage4/unit3/body/conv2/
#                                                                  features/stage4/unit3/body/conv2/
#                                                                  features/stage4/unit3/body/conv2/
#                                                                  features/stage4/unit3/body/conv2/
#                                                                  features/stage4/unit3/body/conv2/
#                                                                  features/stage4/unit3/body/conv2/
#                                                                  features/stage4/unit3/body/conv2/
#                                                                  features/stage4/unit3/body/conv2/
# __________________________________________________________________________________________________
# features/stage4/unit3/body/conv (None, 7, 7, 1024)   4096        features/stage4/unit3/body/conv2/
# __________________________________________________________________________________________________
# features/stage4/unit3/body/conv (None, 7, 7, 1024)   0           features/stage4/unit3/body/conv2/
# __________________________________________________________________________________________________
# features/stage4/unit3/body/conv (None, 7, 7, 2048)   2097152     features/stage4/unit3/body/conv2/
# __________________________________________________________________________________________________
# features/stage4/unit3/body/conv (None, 7, 7, 2048)   8192        features/stage4/unit3/body/conv3/
# __________________________________________________________________________________________________
# features/stage4/unit3/se/pool ( (None, 1, 1, 2048)   0           features/stage4/unit3/body/conv3/
# __________________________________________________________________________________________________
# features/stage4/unit3/se/conv1  (None, 1, 1, 128)    262272      features/stage4/unit3/se/pool[0][
# __________________________________________________________________________________________________
# features/stage4/unit3/se/relu ( (None, 1, 1, 128)    0           features/stage4/unit3/se/conv1[0]
# __________________________________________________________________________________________________
# features/stage4/unit3/se/conv2  (None, 1, 1, 2048)   264192      features/stage4/unit3/se/relu[0][
# __________________________________________________________________________________________________
# features/stage4/unit3/se/sigmoi (None, 1, 1, 2048)   0           features/stage4/unit3/se/conv2[0]
# __________________________________________________________________________________________________
# features/stage4/unit3/se/mul (M (None, 7, 7, 2048)   0           features/stage4/unit3/body/conv3/
#                                                                  features/stage4/unit3/se/sigmoid[
# __________________________________________________________________________________________________
# features/stage4/unit3/add (Add) (None, 7, 7, 2048)   0           features/stage4/unit3/se/mul[0][0
#                                                                  features/stage4/unit2/activ[0][0]
# __________________________________________________________________________________________________
# features/stage4/unit3/activ (Ac (None, 7, 7, 2048)   0           features/stage4/unit3/add[0][0]
# __________________________________________________________________________________________________
# features/final_pool (AveragePoo (None, 1, 1, 2048)   0           features/stage4/unit3/activ[0][0]
# __________________________________________________________________________________________________
# lambda_1092 (Lambda)            (None, 2048)         0           features/final_pool[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 5)            10245       lambda_1092[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 5)            0           dense_1[0][0]
# ==================================================================================================
# Total params: 47,054,517
# Trainable params: 46,916,661
# Non-trainable params: 137,856
# __________________________________________________________________________________________________

# %% [markdown]
# ImageDataGenerator for training and testing

# %%
from keras.preprocessing import image 
from keras.preprocessing.image import ImageDataGenerator

train_datagen = ImageDataGenerator(
    rescale=1./255,
    zoom_range=0.2,
    fill_mode = 'reflect',
    rotation_range = 50,
    horizontal_flip = True,
    vertical_flip = True,
    validation_split = 0.2)

# %%
train_generator = train_datagen.flow_from_directory(
        './train',
        target_size=(224, 224),
        batch_size=20,
        class_mode='categorical',
        subset = "training")

valid_generator = train_datagen.flow_from_directory(
        './train',
        target_size=(224, 224),
        batch_size=20,
        class_mode='categorical',
        subset = "validation")

# %%
x_batch, y_batch = next(train_generator)

# %% [markdown]
# Plot the ImageDataGenerator results

# %%
import matplotlib.pyplot as plt

for i in range (0,20):
    image = x_batch[i]
    plt.imshow(image)
    plt.show()

# %%
from keras.optimizers import Adam
from keras.callbacks import ReduceLROnPlateau

reduce_lr = ReduceLROnPlateau(monitor='val_loss', 
                              factor=0.2,
                              patience=4, 
                              min_lr= 1e-6)

model.compile(loss='categorical_crossentropy',
              optimizer = Adam(lr = 2e-4),
              metrics = ['accuracy'])

# %%
model.fit_generator(generator = train_generator,
                   validation_steps = valid_generator.n // valid_generator.batch_size + 1,
                   validation_data = valid_generator,
                   steps_per_epoch = train_generator.n // train_generator.batch_size + 1,
                    epochs = 10,
                   callbacks = [reduce_lr])

# %%
test_datagen = ImageDataGenerator(
    rescale=1./255)

test_generator=test_datagen.flow_from_directory(
                directory="./test",
                batch_size=20,
                seed=42,
                shuffle=False,
                class_mode=None,
                target_size=(224,224))

STEP_SIZE_TEST = test_generator.n // test_generator.batch_size + 1
test_generator.reset()


pred=model.predict_generator(test_generator,
                steps=STEP_SIZE_TEST,
                verbose=1)

# %% [markdown]
# Output predictions to a csv

# %%
import numpy as np
import pandas as pd 

predicted_class_indices = np.argmax(pred, axis=1)

# %%
predicted_class_indices[:10]

# %%
labels = (train_generator.class_indices)
labels = dict((v,k) for k,v in labels.items())
predictions = [labels[k] for k in predicted_class_indices]
filenames=test_generator.filenames

results__ = []
for result in predicted_class_indices :
    if result == 0:
        results__.append('class1')
    elif result == 1:
        results__.append('class2')
    elif result == 2:
        results__.append('class3')
    elif result == 3: 
        results__.append('class4')
    elif result == 4: 
        results__.append('class5')

print(results__)

results = pd.DataFrame({"Category":results__,
                      "Id":filenames})

# %%
results.head()

# %%
results.Category.value_counts()

# %%
results.head()

# %%
results.to_csv(
    "submission.csv",
    index=False)
